# %%
import tensorflow as tf
import numpy as np
from time import time
from datetime import datetime
import math
import matplotlib.pyplot as plt
from PIL import Image

USE_GPU = False
# Out:
# D:\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
import os

# %%
os.getcwd()
# Out:
# 'E:\\courses\\stat231A\\homework1'

# %%
log = lambda *args: print(datetime.now().strftime('%H:%M:%S'), ':', *args)

# %%
def load_cifar10(num_training=49000, num_validation=1000, num_test=10000):
    cifar10 = tf.keras.datasets.cifar10.load_data()
    (X_train, y_train), (X_test, y_test) = cifar10
    X_train = np.asarray(X_train, dtype=np.float32)
    y_train = np.asarray(y_train, dtype=np.int32).flatten()
    X_test = np.asarray(X_test, dtype=np.float32)
    y_test = np.asarray(y_test, dtype=np.int32).flatten()

    mask = range(num_training, num_training + num_validation)
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = range(num_training)
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = range(num_test)
    X_test = X_test[mask]
    y_test = y_test[mask]

    mean_pixel = X_train.mean(axis=(0, 1, 2), keepdims=True)
    std_pixel = X_train.std(axis=(0, 1, 2), keepdims=True)
    X_train = (X_train - mean_pixel) / std_pixel
    X_val = (X_val - mean_pixel) / std_pixel
    X_test = (X_test - mean_pixel) / std_pixel

    return X_train, y_train, X_val, y_val, X_test, y_test, mean_pixel, std_pixel

# %%
class Dataset(object):
    def __init__(self, X, y, batch_size, shuffle=False):
        assert X.shape[0] == y.shape[0]
        self.X, self.y = X, y
        self.batch_size, self.shuffle = batch_size, shuffle

    def __iter__(self):
        N, B = self.X.shape[0], self.batch_size
        idxs = np.arange(N)
        if self.shuffle:
            np.random.shuffle(idxs)
        return iter((self.X[i:i + B], self.y[i:i + B]) for i in range(0, N, B))

# %%
X_train, y_train, X_val, y_val, X_test, y_test, mean_pixel, std_pixel = load_cifar10()
train_dset = Dataset(X_train, y_train, batch_size=64, shuffle=True)
val_dset = Dataset(X_val, y_val, batch_size=64, shuffle=False)
test_dset = Dataset(X_test, y_test, batch_size=64)

# %%
get_X_train_sample = lambda: next(iter(train_dset))[0][7] * std_pixel + mean_pixel

# %%
def select_device(use_gpu=True):
    from tensorflow.python.client import device_lib
    log(device_lib.list_local_devices())
    device = '/device:GPU:0' if use_gpu else '/CPU:0'
    log('Using device: ', device)
    return device

device = select_device(use_gpu=False)
# Out:
# 12:32:32 : [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 17852544518492867942
# ]
# 12:32:32 : Using device:  /CPU:0

# %%
def flatten(x):
    """
    Input:
    - TensorFlow Tensor of shape (N, D1, ..., DM)

    Output:
    - TensorFlow Tensor of shape (N, D1 * ... * DM)
    """
    ############################################################################
    # TODO: (1.a) Reshape tensor x into shape (N, D1 * ... * DM)               #
    ############################################################################

    input_shape = x.get_shape()
    dim = 1
    for d in input_shape.as_list()[1:]:
        dim *= d if not d == None else 1
    ############################################################################
    #                              END OF YOUR CODE                            #
    ############################################################################
    return tf.reshape(x, [-1, dim])

# %%
def kaiming_normal(shape):
    """
    He et al, *Delving Deep into Rectifiers: Surpassing Human-Level Performance on
    ImageNet Classification, ICCV 2015, https://arxiv.org/abs/1502.01852
    """
    if len(shape) == 2:
        fan_in, fan_out = shape[0], shape[1]
    elif len(shape) == 4:
        fan_in, fan_out = np.prod(shape[:3]), shape[3]
    return tf.random_normal(shape) * np.sqrt(2.0 / fan_in)

# %%
def convnet_init():
    """
    Initialize the weights of a Three-Layer ConvNet, for use with the
    three_layer_convnet function defined above.
    """

    conv_w1 = tf.Variable(kaiming_normal([5, 5, 3, 32]))
    conv_b1 = tf.Variable(tf.zeros(32,))

    conv_w2 = tf.Variable(kaiming_normal([5, 5, 32, 32]))
    conv_b2 = tf.Variable(tf.zeros(32,))

    conv_w3 = tf.Variable(kaiming_normal([5, 5, 32, 64]))
    conv_b3 = tf.Variable(tf.zeros(64,))

    ############################################################################
    # TODO: (1.a), (2.a) Initialize the remaining parameters.                  #
    ############################################################################

    conv_w4 = tf.Variable(kaiming_normal([4, 4, 64, 64]))
    conv_b4 = tf.Variable(tf.zeros(64,))
    conv_w5 =tf.Variable(kaiming_normal([1, 1, 64, 10]))
    conv_b5 = tf.Variable(tf.zeros(10,))

    ############################################################################
    #                             END OF YOUR CODE                             #
    ############################################################################

    params = [conv_w1, conv_b1, conv_w2, conv_b2, conv_w3, conv_b3, conv_w4, conv_b4, conv_w5, conv_b5]

    return params

# %%
def convnet_init_block1_only():
    """
    Initialize the weights of a Three-Layer ConvNet, for use with the
    three_layer_convnet function defined above.
    """

    conv_w1 = tf.Variable(kaiming_normal([5, 5, 3, 32]))
    conv_b1 = tf.Variable(tf.zeros(32,))

    conv_w5 =tf.Variable(kaiming_normal([1, 1, 32, 10]))
    conv_b5 = tf.Variable(tf.zeros(10,))

    params = [conv_w1, conv_b1, conv_w5, conv_b5]

    return params

# %%
def convnet_init_block1_and_block2():
    """
    Initialize the weights of a Three-Layer ConvNet, for use with the
    three_layer_convnet function defined above.
    """

    conv_w1 = tf.Variable(kaiming_normal([5, 5, 3, 32]))
    conv_b1 = tf.Variable(tf.zeros(32,))
    
    conv_w2 = tf.Variable(kaiming_normal([5, 5, 32, 32]))
    conv_b2 = tf.Variable(tf.zeros(32,))

    conv_w5 =tf.Variable(kaiming_normal([1, 1, 32, 10]))
    conv_b5 = tf.Variable(tf.zeros(10,))
    
    params = [conv_w1, conv_b1, conv_w2, conv_b2, conv_w5, conv_b5]

   
    return params

# %%
def convnet_init_block1_block2_and_block3():
    """
    Initialize the weights of a Three-Layer ConvNet, for use with the
    three_layer_convnet function defined above.
    """

    conv_w1 = tf.Variable(kaiming_normal([5, 5, 3, 32]))
    conv_b1 = tf.Variable(tf.zeros(32,))
    
    conv_w2 = tf.Variable(kaiming_normal([5, 5, 32, 32]))
    conv_b2 = tf.Variable(tf.zeros(32,))
    
    conv_w3 = tf.Variable(kaiming_normal([5, 5, 32, 64]))
    conv_b3 = tf.Variable(tf.zeros(64,))

    conv_w5 =tf.Variable(kaiming_normal([1, 1, 64, 10]))
    conv_b5 = tf.Variable(tf.zeros(10,))
    
    params = [conv_w1, conv_b1, conv_w2, conv_b2, conv_w3, conv_b3, conv_w5, conv_b5]

    return params

# %%
def convnet_forward(x, params):
    """
    A three-layer convolutional network.

    Args:
    - x: A TensorFlow Tensor of shape (N, H, W, 3) giving a minibatch of images
    - params: A list of TensorFlow Tensors giving the weights and biases for the network.
    """
    [conv_w1, conv_b1, conv_w2, conv_b2, conv_w3, conv_b3, conv_w4, conv_b4, conv_w5, conv_b5] = params

    # block 1
    x1_1_pad = tf.pad(x, [[0, 0], [2, 2], [2, 2], [0, 0]], mode='CONSTANT', constant_values=0)
    x1_2_conv = tf.nn.conv2d(x1_1_pad, conv_w1, [1, 1, 1, 1], padding='VALID') + conv_b1
    x1_3_pad = tf.pad(x1_2_conv, [[0, 0], [1, 1], [1, 1], [0, 0]], mode='CONSTANT', constant_values=0)
    x1_4_pool = tf.nn.max_pool(x1_3_pad, ksize=[1, 3, 3, 1], strides=[1, 2, 2, 1], padding='VALID')
    x1_5_relu = tf.nn.relu(x1_4_pool)

    # block 2
    x2_1_pad = tf.pad(x1_5_relu, [[0, 0], [2, 2], [2, 2], [0, 0]], mode='CONSTANT', constant_values=0)
    x2_2_conv = tf.nn.conv2d(x2_1_pad, conv_w2, [1, 1, 1, 1], padding='VALID') + conv_b2
    x2_3_relu = tf.nn.relu(x2_2_conv)
    x2_4_pad = tf.pad(x2_3_relu, [[0, 0], [1, 1], [1, 1], [0, 0]], mode='CONSTANT', constant_values=0)
    x2_5_pool = tf.nn.avg_pool(x2_4_pad, ksize=[1, 3, 3, 1], strides=[1, 2, 2, 1], padding='VALID')

    # block 3
    x3_1_pad = tf.pad(x2_5_pool, [[0, 0], [2, 2], [2, 2], [0, 0]], mode='CONSTANT', constant_values=0)
    x3_2_conv = tf.nn.conv2d(x3_1_pad, conv_w3, [1, 1, 1, 1], padding='VALID') + conv_b3
    x3_3_relu = tf.nn.relu(x3_2_conv)
    x3_4_pad = tf.pad(x3_3_relu, [[0, 0], [1, 1], [1, 1], [0, 0]], mode='CONSTANT', constant_values=0)
    x3_5_pool = tf.nn.avg_pool(x3_4_pad, ksize=[1, 3, 3, 1], strides=[1, 2, 2, 1], padding='VALID')

    ############################################################################
    # TODO: (1.a), (2.a) Implement the remaining forward pass.                 #
    ############################################################################
    
    # block 4
    x4_1_conv = tf.nn.conv2d(x3_5_pool, conv_w4, [1, 1, 1, 1], padding="VALID") + conv_b4
    x4_2_relu = tf.nn.relu(x4_1_conv)
    
    #block 5
    x5_1_conv = tf.nn.conv2d(x4_2_relu, conv_w5, [1, 1, 1, 1], padding="VALID") + conv_b5
    
    ############################################################################
    #                              END OF YOUR CODE                            #
    ############################################################################
    print(x3_5_pool)
    logits = flatten(x5_1_conv)

    return logits

# %%
def convnet_forward_block1_only(x, params):
    """
    A three-layer convolutional network.

    Args:
    - x: A TensorFlow Tensor of shape (N, H, W, 3) giving a minibatch of images
    - params: A list of TensorFlow Tensors giving the weights and biases for the network.
    """
    [conv_w1, conv_b1, conv_w5, conv_b5] = params

    # block 1
    x1_1_pad = tf.pad(x, [[0, 0], [2, 2], [2, 2], [0, 0]], mode='CONSTANT', constant_values=0)
    x1_2_conv = tf.nn.conv2d(x1_1_pad, conv_w1, [1, 1, 1, 1], padding='VALID') + conv_b1
    x1_3_pad = tf.pad(x1_2_conv, [[0, 0], [1, 1], [1, 1], [0, 0]], mode='CONSTANT', constant_values=0)
    x1_4_pool = tf.nn.max_pool(x1_3_pad, ksize=[1, 3, 3, 1], strides=[1, 2, 2, 1], padding='VALID')
    x1_5_relu = tf.nn.relu(x1_4_pool)
    
    #block 5
    x5_1_conv = tf.nn.conv2d(x1_5_relu, conv_w5, [1, 1, 1, 1], padding="VALID") + conv_b5

    logits = flatten(x5_1_conv)

    return logits

# %%
def convnet_forward_block1_and_block2(x, params):
    """
    A three-layer convolutional network.

    Args:
    - x: A TensorFlow Tensor of shape (N, H, W, 3) giving a minibatch of images
    - params: A list of TensorFlow Tensors giving the weights and biases for the network.
    """
    [conv_w1, conv_b1, conv_w2, conv_b2, conv_w5, conv_b5] = params


    # block 1
    x1_1_pad = tf.pad(x, [[0, 0], [2, 2], [2, 2], [0, 0]], mode='CONSTANT', constant_values=0)
    x1_2_conv = tf.nn.conv2d(x1_1_pad, conv_w1, [1, 1, 1, 1], padding='VALID') + conv_b1
    x1_3_pad = tf.pad(x1_2_conv, [[0, 0], [1, 1], [1, 1], [0, 0]], mode='CONSTANT', constant_values=0)
    x1_4_pool = tf.nn.max_pool(x1_3_pad, ksize=[1, 3, 3, 1], strides=[1, 2, 2, 1], padding='VALID')
    x1_5_relu = tf.nn.relu(x1_4_pool)
    
    # block 2
    x2_1_pad = tf.pad(x1_5_relu, [[0, 0], [2, 2], [2, 2], [0, 0]], mode='CONSTANT', constant_values=0)
    x2_2_conv = tf.nn.conv2d(x2_1_pad, conv_w2, [1, 1, 1, 1], padding='VALID') + conv_b2
    x2_3_relu = tf.nn.relu(x2_2_conv)
    x2_4_pad = tf.pad(x2_3_relu, [[0, 0], [1, 1], [1, 1], [0, 0]], mode='CONSTANT', constant_values=0)
    x2_5_pool = tf.nn.avg_pool(x2_4_pad, ksize=[1, 3, 3, 1], strides=[1, 2, 2, 1], padding='VALID')
    
    #block 5
    x5_1_conv = tf.nn.conv2d(x2_5_pool, conv_w5, [1, 1, 1, 1], padding="VALID") + conv_b5
    
    logits = flatten(x5_1_conv)

    return logits

# %%
def convnet_forward_block1_block2_and_block3(x, params):
    """
    A three-layer convolutional network.

    Args:
    - x: A TensorFlow Tensor of shape (N, H, W, 3) giving a minibatch of images
    - params: A list of TensorFlow Tensors giving the weights and biases for the network.
    """
    [conv_w1, conv_b1, conv_w2, conv_b2, conv_w3, conv_b3, conv_w5, conv_b5] = params

    # block 1
    x1_1_pad = tf.pad(x, [[0, 0], [2, 2], [2, 2], [0, 0]], mode='CONSTANT', constant_values=0)
    x1_2_conv = tf.nn.conv2d(x1_1_pad, conv_w1, [1, 1, 1, 1], padding='VALID') + conv_b1
    x1_3_pad = tf.pad(x1_2_conv, [[0, 0], [1, 1], [1, 1], [0, 0]], mode='CONSTANT', constant_values=0)
    x1_4_pool = tf.nn.max_pool(x1_3_pad, ksize=[1, 3, 3, 1], strides=[1, 2, 2, 1], padding='VALID')
    x1_5_relu = tf.nn.relu(x1_4_pool)

    # block 2
    x2_1_pad = tf.pad(x1_5_relu, [[0, 0], [2, 2], [2, 2], [0, 0]], mode='CONSTANT', constant_values=0)
    x2_2_conv = tf.nn.conv2d(x2_1_pad, conv_w2, [1, 1, 1, 1], padding='VALID') + conv_b2
    x2_3_relu = tf.nn.relu(x2_2_conv)
    x2_4_pad = tf.pad(x2_3_relu, [[0, 0], [1, 1], [1, 1], [0, 0]], mode='CONSTANT', constant_values=0)
    x2_5_pool = tf.nn.avg_pool(x2_4_pad, ksize=[1, 3, 3, 1], strides=[1, 2, 2, 1], padding='VALID')

    # block 3
    x3_1_pad = tf.pad(x2_5_pool, [[0, 0], [2, 2], [2, 2], [0, 0]], mode='CONSTANT', constant_values=0)
    x3_2_conv = tf.nn.conv2d(x3_1_pad, conv_w3, [1, 1, 1, 1], padding='VALID') + conv_b3
    x3_3_relu = tf.nn.relu(x3_2_conv)
    x3_4_pad = tf.pad(x3_3_relu, [[0, 0], [1, 1], [1, 1], [0, 0]], mode='CONSTANT', constant_values=0)
    x3_5_pool = tf.nn.avg_pool(x3_4_pad, ksize=[1, 3, 3, 1], strides=[1, 2, 2, 1], padding='VALID')
    
    #block 5
    x5_1_conv = tf.nn.conv2d(x3_5_relu, conv_w5, [1, 1, 1, 1], padding="VALID") + conv_b5
    
    logits = flatten(x5_1_conv)

    return logits

# %%
def three_layer_convnet_test():
    tf.reset_default_graph()

    with tf.device(device):
        x = tf.placeholder(tf.float32)

        # block 1
        conv_w1 = tf.zeros([5, 5, 3, 32])
        conv_b1 = tf.zeros(32)

        # block 2
        conv_w2 = tf.zeros([5, 5, 32, 32])
        conv_b2 = tf.zeros(32)

        # block 3
        conv_w3 = tf.zeros([5, 5, 32, 64])
        conv_b3 = tf.zeros(64)

        ############################################################################
        # TODO: (1.a), (2.a) Initialize the parameters.                            #
        ############################################################################

        conv_w4 = tf.Variable(kaiming_normal([4, 4, 64, 64]))
        conv_b4 = tf.Variable(tf.zeros(64,))
        conv_w5 =tf.Variable(kaiming_normal([1, 1, 64, 10]))
        conv_b5 = tf.Variable(tf.zeros(10,))

        ############################################################################
        #                             END OF YOUR CODE                             #
        ############################################################################

        params = [conv_w1, conv_b1, conv_w2, conv_b2, conv_w3, conv_b3, conv_w4, conv_b4, conv_w5, conv_b5]
        logits = convnet_forward(x, params)

    # Inputs to convolutional layers are 4-dimensional arrays with shape [batch_size, height, width, channels]
    x_np = np.zeros((64, 32, 32, 3))

    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        logits_np = sess.run(logits, feed_dict={x: x_np})
        log('logits_np has shape', format(logits_np.shape))


with tf.device('/cpu:0'):
    three_layer_convnet_test()
# Out:
# Tensor("AvgPool_1:0", shape=(?, ?, ?, 64), dtype=float32, device=/device:CPU:0)
# 12:32:35 : logits_np has shape (64, 10)

# %%
def training_step(logits, y, params, learning_rate):
    """
    Set up the part of the computational graph which makes a training step.

    Args:
    - logits: TensorFlow Tensor of shape (N, C) giving classification scores for
      the model.
    - y: TensorFlow Tensor of shape (N,) giving ground-truth labels for scores;
      y[i] == c means that c is the correct class for scores[i].
    - params: List of TensorFlow Tensors giving the weights of the model
    - learning_rate: Python scalar giving the learning rate to use for gradient
      descent step.

    Returns:
    - loss: A TensorFlow Tensor of shape () (scalar) giving the loss for this
      batch of data; evaluating the loss also performs a gradient descent step
      on params (see above).
    """
    # First compute the loss; the first line gives losses for each example in
    # the mini-batch, and the second averages the losses across the batch
    losses = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(losses)

    # Compute the gradient of the loss with respect to each parameter of the the
    # network. This is a very magical function call: TensorFlow internally
    # traverses the computational graph starting at loss backward to each element
    # of params, and uses back-propagation to figure out how to compute gradients;
    # it then adds new operations to the computational graph which compute the
    # requested gradients, and returns a list of TensorFlow Tensors that will
    # contain the requested gradients when evaluated.
    grad_params = tf.gradients(loss, params)

    # Make a gradient descent step on all of the model parameters.
    new_weights = []
    for w, grad_w in zip(params, grad_params):
        new_w = tf.assign_sub(w, learning_rate * grad_w)
        new_weights.append(new_w)

    # Insert a control dependency so that evaluating the loss causes a weight
    # update to happen.
    with tf.control_dependencies(new_weights):
        return tf.identity(loss)

# %%
def train(model_fn, init_fn, learning_rate, epochs, print_every=100):
    """
    Train a model on CIFAR-10.

    Args:
    - model_fn: A Python function that performs the forward pass of the model
      using TensorFlow; it should have the following signature:
      scores = model_fn(x, params) where x is a TensorFlow Tensor giving a
      minibatch of image data, params is a list of TensorFlow Tensors holding
      the model weights, and scores is a TensorFlow Tensor of shape (N, C)
      giving scores for all elements of x.
    - init_fn: A Python function that initializes the parameters of the model.
      It should have the signature params = init_fn() where params is a list
      of TensorFlow Tensors holding the (randomly initialized) weights of the
      model.
    - learning_rate: Python float giving the learning rate to use for SGD.
    """
    # First clear the default graph
    tf.reset_default_graph()
    is_training = tf.placeholder(tf.bool, name='is_training')
    # Set up the computational graph for performing forward and backward passes,
    # and weight updates.
    with tf.device(device):
        # Set up placeholders for the data and labels
        x = tf.placeholder(tf.float32, [None, 32, 32, 3])
        y = tf.placeholder(tf.int32, [None])
        params = init_fn()  # Initialize the model parameters
        scores = model_fn(x, params)  # Forward pass of the model
        loss = training_step(scores, y, params, learning_rate)

    train_losses = []
    test_accuracies = []
    
    current_best_acc = 0

    # Now we actually run the graph many times using the training data
    
    #Saver
    saver = tf.train.Saver()
    with tf.Session() as sess:
        # Initialize variables that will live in the graph
        sess.run(tf.global_variables_initializer())
        for epoch in range(epochs):
            log('epoch {:>4d}/{:>4d}'.format(epoch, epochs))
            epoch_time = time()
            for t, (x_np, y_np) in enumerate(train_dset):
                # Run the graph on a batch of training data; recall that asking
                # TensorFlow to evaluate loss will cause an SGD step to happen.
                feed_dict = {x: x_np, y: y_np}
                loss_np = sess.run(loss, feed_dict=feed_dict)

                # Periodically print the loss and check accuracy on the val set
                if t % print_every == 0:
                    num_correct, num_samples, acc = get_accuracy(sess, val_dset, x, scores, is_training)
                    log('   iteration = {:>4d}, loss = {:>8.4f}, accuracy = {:>8.2f}%'.format(t, loss_np, acc))
                    if  acc > current_best_acc:
                        save_path = saver.save(sess, "E:\\courses\\stat231A\\homework1\\models\\best_model_block1_and_block2.ckpt")
                        print("Model saved in path: %s" % save_path)
                        current_best_acc = acc
                        log("Current_Best_Acc: ", acc)

            train_losses.append(loss_np)
            test_accuracies.append(acc)

            log('epoch {:>4d} took {:>.2f}s'.format(epoch, time()-epoch_time))
        
        log("Finished training")
        save_path = saver.save(sess, "E:\\courses\\stat231A\\homework1\\models\\final_model_block1_and_block2.ckpt")
        return params, sess.run(params), train_losses, test_accuracies

# %%
def get_accuracy(sess, dset, x, logits, is_training=None):
    """
    Check accuracy on a classification model.

    Args:
    - sess: A TensorFlow Session that will be used to run the graph
    - dset: A Dataset object on which to check accuracy
    - x: A TensorFlow placeholder Tensor where input images should be fed
    - scores: A TensorFlow Tensor representing the scores output from the
      model; this is the Tensor we will ask TensorFlow to evaluate.

    Returns: Nothing, but prints the accuracy of the model
    """
    num_correct, num_samples = 0, 0
    for x_batch, y_batch in dset:
        feed_dict = {x: x_batch, is_training: 0}
        scores_np = sess.run(logits, feed_dict=feed_dict)
        y_pred = scores_np.argmax(axis=1)
        num_samples += x_batch.shape[0]
        num_correct += (y_pred == y_batch).sum()
    acc = float(num_correct) / num_samples
    return num_correct, num_samples, 100 * acc

# %%
learning_rate = 0.001
epochs = 100

# %%
params, params_val, train_losses, test_accuracies = train(convnet_forward_block1_and_block2, convnet_init_block1_and_block2, learning_rate, epochs=epochs)
# Out:
# 12:32:37 : epoch    0/ 100
# 12:32:38 :    iteration =    0, loss =   7.5093, accuracy =     0.00%
# 12:32:50 :    iteration =  100, loss =   5.3697, accuracy =     1.20%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 12:32:50 : Current_Best_Acc:  1.2
# 12:33:01 :    iteration =  200, loss =   4.3212, accuracy =    13.80%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 12:33:01 : Current_Best_Acc:  13.8
# 12:33:14 :    iteration =  300, loss =   3.7329, accuracy =    13.60%
# 12:33:29 :    iteration =  400, loss =   3.1941, accuracy =    14.40%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 12:33:29 : Current_Best_Acc:  14.399999999999999
# 12:33:42 :    iteration =  500, loss =   3.1082, accuracy =    13.90%
# 12:33:54 :    iteration =  600, loss =   2.7606, accuracy =    15.10%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 12:33:54 : Current_Best_Acc:  15.1
# 12:34:06 :    iteration =  700, loss =   2.7358, accuracy =    15.40%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 12:34:06 : Current_Best_Acc:  15.4
# 12:34:13 : epoch    0 took 95.61s
# 12:34:13 : epoch    1/ 100
# 12:34:14 :    iteration =    0, loss =   2.6592, accuracy =    15.00%
# 12:34:25 :    iteration =  100, loss =   2.5725, accuracy =    16.30%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 12:34:25 : Current_Best_Acc:  16.3
# 12:34:36 :    iteration =  200, loss =   2.4694, accuracy =    16.30%
# 12:34:48 :    iteration =  300, loss =   2.4100, accuracy =    16.60%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 12:34:48 : Current_Best_Acc:  16.6
# 12:34:59 :    iteration =  400, loss =   2.4400, accuracy =    17.80%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 12:34:59 : Current_Best_Acc:  17.8
# 12:35:10 :    iteration =  500, loss =   2.4620, accuracy =    17.50%
# 12:35:22 :    iteration =  600, loss =   2.3565, accuracy =    18.40%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 12:35:22 : Current_Best_Acc:  18.4
# 12:35:33 :    iteration =  700, loss =   2.4112, accuracy =    18.30%
# 12:35:40 : epoch    1 took 86.77s
# 12:35:40 : epoch    2/ 100
# 12:35:40 :    iteration =    0, loss =   2.3671, accuracy =    17.50%
# 12:35:52 :    iteration =  100, loss =   2.3649, accuracy =    17.60%
# 12:36:03 :    iteration =  200, loss =   2.2691, accuracy =    18.80%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 12:36:03 : Current_Best_Acc:  18.8
# 12:36:14 :    iteration =  300, loss =   2.2538, accuracy =    19.00%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 12:36:14 : Current_Best_Acc:  19.0
# 12:36:26 :    iteration =  400, loss =   2.3229, accuracy =    18.90%
# 12:36:38 :    iteration =  500, loss =   2.3018, accuracy =    19.00%
# 12:36:50 :    iteration =  600, loss =   2.2635, accuracy =    19.50%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 12:36:50 : Current_Best_Acc:  19.5
# 12:37:02 :    iteration =  700, loss =   2.3174, accuracy =    19.00%
# 12:37:09 : epoch    2 took 89.57s
# 12:37:09 : epoch    3/ 100
# 12:37:10 :    iteration =    0, loss =   2.2739, accuracy =    19.20%
# 12:37:22 :    iteration =  100, loss =   2.2900, accuracy =    18.50%
# 12:37:34 :    iteration =  200, loss =   2.1822, accuracy =    19.60%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 12:37:34 : Current_Best_Acc:  19.6
# 12:37:46 :    iteration =  300, loss =   2.1906, accuracy =    19.60%
# 12:37:57 :    iteration =  400, loss =   2.2699, accuracy =    19.50%
# 12:38:09 :    iteration =  500, loss =   2.2276, accuracy =    18.50%
# 12:38:20 :    iteration =  600, loss =   2.2154, accuracy =    20.10%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 12:38:20 : Current_Best_Acc:  20.1
# 12:38:32 :    iteration =  700, loss =   2.2738, accuracy =    19.60%
# 12:38:39 : epoch    3 took 89.69s
# 12:38:39 : epoch    4/ 100
# 12:38:40 :    iteration =    0, loss =   2.2246, accuracy =    20.20%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 12:38:40 : Current_Best_Acc:  20.200000000000003
# 12:38:51 :    iteration =  100, loss =   2.2495, accuracy =    19.60%
# 12:39:03 :    iteration =  200, loss =   2.1324, accuracy =    20.60%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 12:39:03 : Current_Best_Acc:  20.599999999999998
# 12:39:15 :    iteration =  300, loss =   2.1528, accuracy =    19.70%
# 12:39:26 :    iteration =  400, loss =   2.2364, accuracy =    20.50%
# 12:39:38 :    iteration =  500, loss =   2.1850, accuracy =    19.60%
# 12:39:49 :    iteration =  600, loss =   2.1835, accuracy =    21.00%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 12:39:49 : Current_Best_Acc:  21.0
# 12:40:01 :    iteration =  700, loss =   2.2479, accuracy =    19.90%
# 12:40:08 : epoch    4 took 89.00s
# 12:40:08 : epoch    5/ 100
# 12:40:09 :    iteration =    0, loss =   2.1914, accuracy =    20.80%
# 12:40:20 :    iteration =  100, loss =   2.2212, accuracy =    20.40%
# 12:40:32 :    iteration =  200, loss =   2.0989, accuracy =    20.90%
# 12:40:43 :    iteration =  300, loss =   2.1254, accuracy =    21.00%
# 12:40:55 :    iteration =  400, loss =   2.2121, accuracy =    21.20%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 12:40:55 : Current_Best_Acc:  21.2
# 12:41:07 :    iteration =  500, loss =   2.1561, accuracy =    21.00%
# 12:41:18 :    iteration =  600, loss =   2.1599, accuracy =    22.00%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 12:41:18 : Current_Best_Acc:  22.0
# 12:41:31 :    iteration =  700, loss =   2.2308, accuracy =    21.10%
# 12:41:38 : epoch    5 took 90.29s
# 12:41:38 : epoch    6/ 100
# 12:41:39 :    iteration =    0, loss =   2.1679, accuracy =    21.60%
# 12:41:51 :    iteration =  100, loss =   2.1998, accuracy =    21.10%
# 12:42:03 :    iteration =  200, loss =   2.0733, accuracy =    22.20%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 12:42:03 : Current_Best_Acc:  22.2
# 12:42:15 :    iteration =  300, loss =   2.1056, accuracy =    22.30%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 12:42:15 : Current_Best_Acc:  22.3
# 12:42:27 :    iteration =  400, loss =   2.1927, accuracy =    22.10%
# 12:42:39 :    iteration =  500, loss =   2.1344, accuracy =    21.70%
# 12:42:52 :    iteration =  600, loss =   2.1399, accuracy =    22.20%
# 12:43:03 :    iteration =  700, loss =   2.2192, accuracy =    21.20%
# 12:43:10 : epoch    6 took 92.31s
# 12:43:10 : epoch    7/ 100
# 12:43:11 :    iteration =    0, loss =   2.1505, accuracy =    22.40%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 12:43:11 : Current_Best_Acc:  22.400000000000002
# 12:43:23 :    iteration =  100, loss =   2.1824, accuracy =    22.60%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 12:43:23 : Current_Best_Acc:  22.6
# 12:43:35 :    iteration =  200, loss =   2.0526, accuracy =    23.20%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 12:43:35 : Current_Best_Acc:  23.200000000000003
# 12:43:47 :    iteration =  300, loss =   2.0886, accuracy =    23.00%
# 12:43:58 :    iteration =  400, loss =   2.1760, accuracy =    22.40%
# 12:44:10 :    iteration =  500, loss =   2.1178, accuracy =    22.20%
# 12:44:22 :    iteration =  600, loss =   2.1230, accuracy =    22.50%
# 12:44:33 :    iteration =  700, loss =   2.2098, accuracy =    21.90%
# 12:44:40 : epoch    7 took 89.85s
# 12:44:40 : epoch    8/ 100
# 12:44:41 :    iteration =    0, loss =   2.1366, accuracy =    22.80%
# 12:44:53 :    iteration =  100, loss =   2.1676, accuracy =    22.80%
# 12:45:04 :    iteration =  200, loss =   2.0358, accuracy =    23.30%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 12:45:04 : Current_Best_Acc:  23.3
# 12:45:16 :    iteration =  300, loss =   2.0764, accuracy =    23.30%
# 12:45:28 :    iteration =  400, loss =   2.1619, accuracy =    22.90%
# 12:45:39 :    iteration =  500, loss =   2.1048, accuracy =    23.10%
# 12:45:51 :    iteration =  600, loss =   2.1105, accuracy =    22.70%
# 12:46:03 :    iteration =  700, loss =   2.2026, accuracy =    22.10%
# 12:46:10 : epoch    8 took 89.87s
# 12:46:10 : epoch    9/ 100
# 12:46:11 :    iteration =    0, loss =   2.1255, accuracy =    23.40%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 12:46:11 : Current_Best_Acc:  23.400000000000002
# 12:46:23 :    iteration =  100, loss =   2.1555, accuracy =    22.90%
# 12:46:35 :    iteration =  200, loss =   2.0213, accuracy =    23.70%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 12:46:35 : Current_Best_Acc:  23.7
# 12:46:46 :    iteration =  300, loss =   2.0665, accuracy =    23.70%
# 12:46:58 :    iteration =  400, loss =   2.1504, accuracy =    23.80%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 12:46:59 : Current_Best_Acc:  23.799999999999997
# 12:47:10 :    iteration =  500, loss =   2.0951, accuracy =    22.80%
# 12:47:23 :    iteration =  600, loss =   2.0999, accuracy =    23.40%
# 12:47:35 :    iteration =  700, loss =   2.1966, accuracy =    22.00%
# 12:47:42 : epoch    9 took 92.23s
# 12:47:42 : epoch   10/ 100
# 12:47:43 :    iteration =    0, loss =   2.1160, accuracy =    24.00%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 12:47:43 : Current_Best_Acc:  24.0
# 12:47:56 :    iteration =  100, loss =   2.1440, accuracy =    23.20%
# 12:48:09 :    iteration =  200, loss =   2.0091, accuracy =    23.40%
# 12:48:20 :    iteration =  300, loss =   2.0588, accuracy =    25.00%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 12:48:20 : Current_Best_Acc:  25.0
# 12:48:32 :    iteration =  400, loss =   2.1413, accuracy =    24.50%
# 12:48:44 :    iteration =  500, loss =   2.0881, accuracy =    23.90%
# 12:48:55 :    iteration =  600, loss =   2.0908, accuracy =    24.20%
# 12:49:07 :    iteration =  700, loss =   2.1910, accuracy =    22.60%
# 12:49:14 : epoch   10 took 91.55s
# 12:49:14 : epoch   11/ 100
# 12:49:15 :    iteration =    0, loss =   2.1082, accuracy =    24.70%
# 12:49:26 :    iteration =  100, loss =   2.1345, accuracy =    24.10%
# 12:49:38 :    iteration =  200, loss =   1.9989, accuracy =    24.80%
# 12:49:49 :    iteration =  300, loss =   2.0524, accuracy =    25.40%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 12:49:49 : Current_Best_Acc:  25.4
# 12:50:01 :    iteration =  400, loss =   2.1334, accuracy =    24.70%
# 12:50:13 :    iteration =  500, loss =   2.0832, accuracy =    23.90%
# 12:50:24 :    iteration =  600, loss =   2.0826, accuracy =    25.00%
# 12:50:36 :    iteration =  700, loss =   2.1864, accuracy =    23.40%
# 12:50:43 : epoch   11 took 88.71s
# 12:50:43 : epoch   12/ 100
# 12:50:43 :    iteration =    0, loss =   2.1013, accuracy =    25.00%
# 12:50:55 :    iteration =  100, loss =   2.1266, accuracy =    24.30%
# 12:51:07 :    iteration =  200, loss =   1.9904, accuracy =    24.80%
# 12:51:18 :    iteration =  300, loss =   2.0474, accuracy =    25.30%
# 12:51:30 :    iteration =  400, loss =   2.1259, accuracy =    25.80%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 12:51:30 : Current_Best_Acc:  25.8
# 12:51:42 :    iteration =  500, loss =   2.0801, accuracy =    24.60%
# 12:51:53 :    iteration =  600, loss =   2.0758, accuracy =    24.80%
# 12:52:05 :    iteration =  700, loss =   2.1824, accuracy =    23.20%
# 12:52:12 : epoch   12 took 89.09s
# 12:52:12 : epoch   13/ 100
# 12:52:13 :    iteration =    0, loss =   2.0955, accuracy =    25.80%
# 12:52:24 :    iteration =  100, loss =   2.1196, accuracy =    23.90%
# 12:52:36 :    iteration =  200, loss =   1.9835, accuracy =    25.30%
# 12:52:47 :    iteration =  300, loss =   2.0434, accuracy =    24.90%
# 12:52:59 :    iteration =  400, loss =   2.1197, accuracy =    25.80%
# 12:53:11 :    iteration =  500, loss =   2.0780, accuracy =    25.00%
# 12:53:22 :    iteration =  600, loss =   2.0698, accuracy =    25.10%
# 12:53:34 :    iteration =  700, loss =   2.1787, accuracy =    23.60%
# 12:53:41 : epoch   13 took 89.03s
# 12:53:41 : epoch   14/ 100
# 12:53:42 :    iteration =    0, loss =   2.0904, accuracy =    26.10%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 12:53:42 : Current_Best_Acc:  26.1
# 12:53:53 :    iteration =  100, loss =   2.1137, accuracy =    24.20%
# 12:54:05 :    iteration =  200, loss =   1.9777, accuracy =    25.40%
# 12:54:16 :    iteration =  300, loss =   2.0404, accuracy =    24.80%
# 12:54:28 :    iteration =  400, loss =   2.1145, accuracy =    25.80%
# 12:54:40 :    iteration =  500, loss =   2.0770, accuracy =    24.70%
# 12:54:51 :    iteration =  600, loss =   2.0643, accuracy =    25.70%
# 12:55:03 :    iteration =  700, loss =   2.1753, accuracy =    24.10%
# 12:55:10 : epoch   14 took 89.17s
# 12:55:10 : epoch   15/ 100
# 12:55:11 :    iteration =    0, loss =   2.0859, accuracy =    26.10%
# 12:55:22 :    iteration =  100, loss =   2.1084, accuracy =    24.80%
# 12:55:34 :    iteration =  200, loss =   1.9727, accuracy =    25.70%
# 12:55:46 :    iteration =  300, loss =   2.0382, accuracy =    25.20%
# 12:55:57 :    iteration =  400, loss =   2.1102, accuracy =    25.50%
# 12:56:09 :    iteration =  500, loss =   2.0761, accuracy =    25.10%
# 12:56:20 :    iteration =  600, loss =   2.0592, accuracy =    26.10%
# 12:56:32 :    iteration =  700, loss =   2.1724, accuracy =    24.60%
# 12:56:39 : epoch   15 took 89.05s
# 12:56:39 : epoch   16/ 100
# 12:56:40 :    iteration =    0, loss =   2.0819, accuracy =    26.20%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 12:56:40 : Current_Best_Acc:  26.200000000000003
# 12:56:51 :    iteration =  100, loss =   2.1034, accuracy =    25.30%
# 12:57:03 :    iteration =  200, loss =   1.9685, accuracy =    26.40%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 12:57:03 : Current_Best_Acc:  26.400000000000002
# 12:57:15 :    iteration =  300, loss =   2.0362, accuracy =    24.90%
# 12:57:26 :    iteration =  400, loss =   2.1061, accuracy =    25.90%
# 12:57:38 :    iteration =  500, loss =   2.0754, accuracy =    25.10%
# 12:57:49 :    iteration =  600, loss =   2.0544, accuracy =    26.10%
# 12:58:01 :    iteration =  700, loss =   2.1700, accuracy =    24.80%
# 12:58:08 : epoch   16 took 89.10s
# 12:58:08 : epoch   17/ 100
# 12:58:09 :    iteration =    0, loss =   2.0784, accuracy =    25.80%
# 12:58:20 :    iteration =  100, loss =   2.0990, accuracy =    25.30%
# 12:58:32 :    iteration =  200, loss =   1.9647, accuracy =    26.90%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 12:58:32 : Current_Best_Acc:  26.900000000000002
# 12:58:44 :    iteration =  300, loss =   2.0348, accuracy =    25.20%
# 12:58:55 :    iteration =  400, loss =   2.1026, accuracy =    26.00%
# 12:59:07 :    iteration =  500, loss =   2.0752, accuracy =    24.90%
# 12:59:19 :    iteration =  600, loss =   2.0501, accuracy =    26.50%
# 12:59:30 :    iteration =  700, loss =   2.1678, accuracy =    24.70%
# 12:59:37 : epoch   17 took 89.03s
# 12:59:37 : epoch   18/ 100
# 12:59:38 :    iteration =    0, loss =   2.0750, accuracy =    25.80%
# 12:59:50 :    iteration =  100, loss =   2.0947, accuracy =    25.90%
# 13:00:01 :    iteration =  200, loss =   1.9614, accuracy =    26.50%
# 13:00:13 :    iteration =  300, loss =   2.0332, accuracy =    25.50%
# 13:00:24 :    iteration =  400, loss =   2.0998, accuracy =    26.00%
# 13:00:36 :    iteration =  500, loss =   2.0752, accuracy =    24.80%
# 13:00:48 :    iteration =  600, loss =   2.0465, accuracy =    26.30%
# 13:00:59 :    iteration =  700, loss =   2.1658, accuracy =    24.90%
# 13:01:07 : epoch   18 took 89.41s
# 13:01:07 : epoch   19/ 100
# 13:01:07 :    iteration =    0, loss =   2.0715, accuracy =    25.70%
# 13:01:19 :    iteration =  100, loss =   2.0905, accuracy =    25.50%
# 13:01:31 :    iteration =  200, loss =   1.9589, accuracy =    26.40%
# 13:01:42 :    iteration =  300, loss =   2.0319, accuracy =    26.00%
# 13:01:54 :    iteration =  400, loss =   2.0972, accuracy =    26.00%
# 13:02:05 :    iteration =  500, loss =   2.0755, accuracy =    25.20%
# 13:02:17 :    iteration =  600, loss =   2.0431, accuracy =    26.00%
# 13:02:29 :    iteration =  700, loss =   2.1636, accuracy =    25.40%
# 13:02:36 : epoch   19 took 89.25s
# 13:02:36 : epoch   20/ 100
# 13:02:37 :    iteration =    0, loss =   2.0678, accuracy =    25.70%
# 13:02:48 :    iteration =  100, loss =   2.0865, accuracy =    25.80%
# 13:03:00 :    iteration =  200, loss =   1.9566, accuracy =    26.20%
# 13:03:12 :    iteration =  300, loss =   2.0306, accuracy =    25.70%
# 13:03:23 :    iteration =  400, loss =   2.0951, accuracy =    25.60%
# 13:03:35 :    iteration =  500, loss =   2.0759, accuracy =    25.10%
# 13:03:47 :    iteration =  600, loss =   2.0399, accuracy =    25.50%
# 13:03:58 :    iteration =  700, loss =   2.1616, accuracy =    25.70%
# 13:04:05 : epoch   20 took 89.34s
# 13:04:05 : epoch   21/ 100
# 13:04:06 :    iteration =    0, loss =   2.0642, accuracy =    25.70%
# 13:04:18 :    iteration =  100, loss =   2.0827, accuracy =    25.90%
# 13:04:29 :    iteration =  200, loss =   1.9543, accuracy =    26.60%
# 13:04:41 :    iteration =  300, loss =   2.0292, accuracy =    25.20%
# 13:04:52 :    iteration =  400, loss =   2.0931, accuracy =    25.70%
# 13:05:04 :    iteration =  500, loss =   2.0766, accuracy =    24.80%
# 13:05:16 :    iteration =  600, loss =   2.0372, accuracy =    25.40%
# 13:05:27 :    iteration =  700, loss =   2.1600, accuracy =    25.80%
# 13:05:34 : epoch   21 took 89.02s
# 13:05:34 : epoch   22/ 100
# 13:05:35 :    iteration =    0, loss =   2.0612, accuracy =    25.80%
# 13:05:47 :    iteration =  100, loss =   2.0793, accuracy =    26.20%
# 13:05:58 :    iteration =  200, loss =   1.9515, accuracy =    26.50%
# 13:06:10 :    iteration =  300, loss =   2.0279, accuracy =    25.40%
# 13:06:21 :    iteration =  400, loss =   2.0918, accuracy =    25.70%
# 13:06:33 :    iteration =  500, loss =   2.0769, accuracy =    24.50%
# 13:06:45 :    iteration =  600, loss =   2.0345, accuracy =    25.00%
# 13:06:56 :    iteration =  700, loss =   2.1585, accuracy =    25.80%
# 13:07:03 : epoch   22 took 89.06s
# 13:07:03 : epoch   23/ 100
# 13:07:04 :    iteration =    0, loss =   2.0587, accuracy =    25.50%
# 13:07:16 :    iteration =  100, loss =   2.0762, accuracy =    25.90%
# 13:07:28 :    iteration =  200, loss =   1.9485, accuracy =    26.50%
# 13:07:40 :    iteration =  300, loss =   2.0263, accuracy =    25.80%
# 13:07:51 :    iteration =  400, loss =   2.0912, accuracy =    25.60%
# 13:08:03 :    iteration =  500, loss =   2.0770, accuracy =    24.60%
# 13:08:14 :    iteration =  600, loss =   2.0323, accuracy =    25.00%
# 13:08:26 :    iteration =  700, loss =   2.1569, accuracy =    25.90%
# 13:08:33 : epoch   23 took 90.00s
# 13:08:33 : epoch   24/ 100
# 13:08:34 :    iteration =    0, loss =   2.0562, accuracy =    25.50%
# 13:08:46 :    iteration =  100, loss =   2.0735, accuracy =    25.70%
# 13:08:57 :    iteration =  200, loss =   1.9459, accuracy =    26.40%
# 13:09:09 :    iteration =  300, loss =   2.0252, accuracy =    25.70%
# 13:09:20 :    iteration =  400, loss =   2.0901, accuracy =    25.60%
# 13:09:32 :    iteration =  500, loss =   2.0770, accuracy =    24.60%
# 13:09:44 :    iteration =  600, loss =   2.0301, accuracy =    25.20%
# 13:09:55 :    iteration =  700, loss =   2.1552, accuracy =    25.80%
# 13:10:02 : epoch   24 took 89.06s
# 13:10:02 : epoch   25/ 100
# 13:10:03 :    iteration =    0, loss =   2.0544, accuracy =    25.40%
# 13:10:15 :    iteration =  100, loss =   2.0708, accuracy =    25.50%
# 13:10:26 :    iteration =  200, loss =   1.9440, accuracy =    26.80%
# 13:10:38 :    iteration =  300, loss =   2.0241, accuracy =    25.60%
# 13:10:50 :    iteration =  400, loss =   2.0890, accuracy =    25.70%
# 13:11:01 :    iteration =  500, loss =   2.0769, accuracy =    24.60%
# 13:11:13 :    iteration =  600, loss =   2.0279, accuracy =    25.30%
# 13:11:24 :    iteration =  700, loss =   2.1533, accuracy =    25.80%
# 13:11:31 : epoch   25 took 89.13s
# 13:11:31 : epoch   26/ 100
# 13:11:32 :    iteration =    0, loss =   2.0524, accuracy =    25.50%
# 13:11:44 :    iteration =  100, loss =   2.0681, accuracy =    25.60%
# 13:11:55 :    iteration =  200, loss =   1.9419, accuracy =    26.80%
# 13:12:07 :    iteration =  300, loss =   2.0230, accuracy =    25.50%
# 13:12:19 :    iteration =  400, loss =   2.0880, accuracy =    26.00%
# 13:12:30 :    iteration =  500, loss =   2.0768, accuracy =    24.50%
# 13:12:42 :    iteration =  600, loss =   2.0258, accuracy =    25.00%
# 13:12:53 :    iteration =  700, loss =   2.1515, accuracy =    25.90%
# 13:13:00 : epoch   26 took 89.07s
# 13:13:00 : epoch   27/ 100
# 13:13:01 :    iteration =    0, loss =   2.0506, accuracy =    25.20%
# 13:13:13 :    iteration =  100, loss =   2.0657, accuracy =    26.00%
# 13:13:24 :    iteration =  200, loss =   1.9399, accuracy =    27.10%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 13:13:24 : Current_Best_Acc:  27.1
# 13:13:36 :    iteration =  300, loss =   2.0221, accuracy =    25.50%
# 13:13:48 :    iteration =  400, loss =   2.0869, accuracy =    26.10%
# 13:13:59 :    iteration =  500, loss =   2.0768, accuracy =    24.50%
# 13:14:11 :    iteration =  600, loss =   2.0240, accuracy =    24.80%
# 13:14:22 :    iteration =  700, loss =   2.1498, accuracy =    25.70%
# 13:14:29 : epoch   27 took 89.00s
# 13:14:29 : epoch   28/ 100
# 13:14:30 :    iteration =    0, loss =   2.0488, accuracy =    25.40%
# 13:14:42 :    iteration =  100, loss =   2.0633, accuracy =    26.00%
# 13:14:53 :    iteration =  200, loss =   1.9381, accuracy =    27.10%
# 13:15:05 :    iteration =  300, loss =   2.0209, accuracy =    25.20%
# 13:15:17 :    iteration =  400, loss =   2.0857, accuracy =    26.30%
# 13:15:29 :    iteration =  500, loss =   2.0768, accuracy =    24.50%
# 13:15:40 :    iteration =  600, loss =   2.0224, accuracy =    24.90%
# 13:15:52 :    iteration =  700, loss =   2.1485, accuracy =    25.70%
# 13:15:59 : epoch   28 took 89.83s
# 13:15:59 : epoch   29/ 100
# 13:16:00 :    iteration =    0, loss =   2.0466, accuracy =    25.10%
# 13:16:13 :    iteration =  100, loss =   2.0613, accuracy =    26.20%
# 13:16:26 :    iteration =  200, loss =   1.9361, accuracy =    26.80%
# 13:16:39 :    iteration =  300, loss =   2.0198, accuracy =    25.10%
# 13:16:51 :    iteration =  400, loss =   2.0846, accuracy =    26.30%
# 13:17:02 :    iteration =  500, loss =   2.0769, accuracy =    24.70%
# 13:17:14 :    iteration =  600, loss =   2.0209, accuracy =    25.30%
# 13:17:26 :    iteration =  700, loss =   2.1470, accuracy =    25.90%
# 13:17:32 : epoch   29 took 93.17s
# 13:17:32 : epoch   30/ 100
# 13:17:33 :    iteration =    0, loss =   2.0448, accuracy =    25.20%
# 13:17:45 :    iteration =  100, loss =   2.0591, accuracy =    25.90%
# 13:17:57 :    iteration =  200, loss =   1.9342, accuracy =    26.90%
# 13:18:08 :    iteration =  300, loss =   2.0189, accuracy =    25.10%
# 13:18:19 :    iteration =  400, loss =   2.0837, accuracy =    26.10%
# 13:18:31 :    iteration =  500, loss =   2.0769, accuracy =    24.80%
# 13:18:42 :    iteration =  600, loss =   2.0195, accuracy =    25.40%
# 13:18:54 :    iteration =  700, loss =   2.1455, accuracy =    26.20%
# 13:19:01 : epoch   30 took 88.65s
# 13:19:01 : epoch   31/ 100
# 13:19:02 :    iteration =    0, loss =   2.0429, accuracy =    25.40%
# 13:19:13 :    iteration =  100, loss =   2.0571, accuracy =    26.10%
# 13:19:25 :    iteration =  200, loss =   1.9324, accuracy =    26.90%
# 13:19:37 :    iteration =  300, loss =   2.0180, accuracy =    25.10%
# 13:19:49 :    iteration =  400, loss =   2.0829, accuracy =    26.20%
# 13:20:00 :    iteration =  500, loss =   2.0767, accuracy =    24.50%
# 13:20:13 :    iteration =  600, loss =   2.0182, accuracy =    25.40%
# 13:20:25 :    iteration =  700, loss =   2.1439, accuracy =    26.40%
# 13:20:32 : epoch   31 took 91.29s
# 13:20:32 : epoch   32/ 100
# 13:20:33 :    iteration =    0, loss =   2.0410, accuracy =    25.50%
# 13:20:45 :    iteration =  100, loss =   2.0551, accuracy =    26.20%
# 13:20:57 :    iteration =  200, loss =   1.9307, accuracy =    27.10%
# 13:21:09 :    iteration =  300, loss =   2.0172, accuracy =    25.40%
# 13:21:21 :    iteration =  400, loss =   2.0822, accuracy =    26.40%
# 13:21:33 :    iteration =  500, loss =   2.0765, accuracy =    24.40%
# 13:21:47 :    iteration =  600, loss =   2.0168, accuracy =    25.90%
# 13:21:58 :    iteration =  700, loss =   2.1427, accuracy =    26.60%
# 13:22:05 : epoch   32 took 92.97s
# 13:22:05 : epoch   33/ 100
# 13:22:06 :    iteration =    0, loss =   2.0392, accuracy =    25.40%
# 13:22:17 :    iteration =  100, loss =   2.0529, accuracy =    26.30%
# 13:22:29 :    iteration =  200, loss =   1.9295, accuracy =    27.40%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 13:22:29 : Current_Best_Acc:  27.400000000000002
# 13:22:40 :    iteration =  300, loss =   2.0162, accuracy =    25.40%
# 13:22:51 :    iteration =  400, loss =   2.0816, accuracy =    26.30%
# 13:23:02 :    iteration =  500, loss =   2.0763, accuracy =    24.50%
# 13:23:13 :    iteration =  600, loss =   2.0153, accuracy =    26.20%
# 13:23:25 :    iteration =  700, loss =   2.1416, accuracy =    26.70%
# 13:23:32 : epoch   33 took 86.20s
# 13:23:32 : epoch   34/ 100
# 13:23:32 :    iteration =    0, loss =   2.0373, accuracy =    25.60%
# 13:23:44 :    iteration =  100, loss =   2.0509, accuracy =    26.30%
# 13:23:55 :    iteration =  200, loss =   1.9282, accuracy =    27.40%
# 13:24:06 :    iteration =  300, loss =   2.0152, accuracy =    25.60%
# 13:24:17 :    iteration =  400, loss =   2.0806, accuracy =    26.40%
# 13:24:29 :    iteration =  500, loss =   2.0759, accuracy =    24.90%
# 13:24:40 :    iteration =  600, loss =   2.0139, accuracy =    26.00%
# 13:24:51 :    iteration =  700, loss =   2.1406, accuracy =    26.70%
# 13:24:58 : epoch   34 took 86.46s
# 13:24:58 : epoch   35/ 100
# 13:24:59 :    iteration =    0, loss =   2.0356, accuracy =    25.80%
# 13:25:10 :    iteration =  100, loss =   2.0488, accuracy =    26.40%
# 13:25:21 :    iteration =  200, loss =   1.9267, accuracy =    27.50%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 13:25:21 : Current_Best_Acc:  27.500000000000004
# 13:25:32 :    iteration =  300, loss =   2.0141, accuracy =    25.50%
# 13:25:44 :    iteration =  400, loss =   2.0801, accuracy =    26.40%
# 13:25:55 :    iteration =  500, loss =   2.0756, accuracy =    25.00%
# 13:26:07 :    iteration =  600, loss =   2.0121, accuracy =    25.90%
# 13:26:18 :    iteration =  700, loss =   2.1394, accuracy =    26.70%
# 13:26:25 : epoch   35 took 86.82s
# 13:26:25 : epoch   36/ 100
# 13:26:26 :    iteration =    0, loss =   2.0340, accuracy =    25.90%
# 13:26:37 :    iteration =  100, loss =   2.0467, accuracy =    26.30%
# 13:26:48 :    iteration =  200, loss =   1.9252, accuracy =    27.30%
# 13:26:59 :    iteration =  300, loss =   2.0130, accuracy =    25.70%
# 13:27:10 :    iteration =  400, loss =   2.0795, accuracy =    26.50%
# 13:27:22 :    iteration =  500, loss =   2.0751, accuracy =    25.00%
# 13:27:33 :    iteration =  600, loss =   2.0104, accuracy =    26.10%
# 13:27:44 :    iteration =  700, loss =   2.1382, accuracy =    26.80%
# 13:27:51 : epoch   36 took 86.10s
# 13:27:51 : epoch   37/ 100
# 13:27:52 :    iteration =    0, loss =   2.0327, accuracy =    26.10%
# 13:28:03 :    iteration =  100, loss =   2.0448, accuracy =    26.50%
# 13:28:14 :    iteration =  200, loss =   1.9241, accuracy =    27.20%
# 13:28:25 :    iteration =  300, loss =   2.0120, accuracy =    25.90%
# 13:28:37 :    iteration =  400, loss =   2.0790, accuracy =    26.60%
# 13:28:48 :    iteration =  500, loss =   2.0748, accuracy =    25.20%
# 13:28:59 :    iteration =  600, loss =   2.0090, accuracy =    26.30%
# 13:29:10 :    iteration =  700, loss =   2.1370, accuracy =    26.60%
# 13:29:17 : epoch   37 took 86.31s
# 13:29:17 : epoch   38/ 100
# 13:29:18 :    iteration =    0, loss =   2.0312, accuracy =    26.20%
# 13:29:29 :    iteration =  100, loss =   2.0428, accuracy =    26.60%
# 13:29:40 :    iteration =  200, loss =   1.9229, accuracy =    27.20%
# 13:29:52 :    iteration =  300, loss =   2.0111, accuracy =    25.80%
# 13:30:03 :    iteration =  400, loss =   2.0784, accuracy =    26.50%
# 13:30:14 :    iteration =  500, loss =   2.0743, accuracy =    25.40%
# 13:30:25 :    iteration =  600, loss =   2.0075, accuracy =    26.30%
# 13:30:37 :    iteration =  700, loss =   2.1358, accuracy =    26.70%
# 13:30:43 : epoch   38 took 86.08s
# 13:30:43 : epoch   39/ 100
# 13:30:44 :    iteration =    0, loss =   2.0296, accuracy =    26.50%
# 13:30:55 :    iteration =  100, loss =   2.0410, accuracy =    26.60%
# 13:31:07 :    iteration =  200, loss =   1.9217, accuracy =    27.30%
# 13:31:18 :    iteration =  300, loss =   2.0100, accuracy =    25.70%
# 13:31:29 :    iteration =  400, loss =   2.0777, accuracy =    26.80%
# 13:31:41 :    iteration =  500, loss =   2.0737, accuracy =    25.50%
# 13:31:52 :    iteration =  600, loss =   2.0060, accuracy =    26.30%
# 13:32:03 :    iteration =  700, loss =   2.1347, accuracy =    26.80%
# 13:32:10 : epoch   39 took 86.77s
# 13:32:10 : epoch   40/ 100
# 13:32:11 :    iteration =    0, loss =   2.0283, accuracy =    26.50%
# 13:32:22 :    iteration =  100, loss =   2.0391, accuracy =    26.50%
# 13:32:33 :    iteration =  200, loss =   1.9205, accuracy =    27.40%
# 13:32:45 :    iteration =  300, loss =   2.0089, accuracy =    25.70%
# 13:32:56 :    iteration =  400, loss =   2.0773, accuracy =    26.90%
# 13:33:08 :    iteration =  500, loss =   2.0732, accuracy =    25.60%
# 13:33:19 :    iteration =  600, loss =   2.0045, accuracy =    26.40%
# 13:33:30 :    iteration =  700, loss =   2.1335, accuracy =    26.80%
# 13:33:37 : epoch   40 took 86.98s
# 13:33:37 : epoch   41/ 100
# 13:33:38 :    iteration =    0, loss =   2.0271, accuracy =    26.20%
# 13:33:49 :    iteration =  100, loss =   2.0371, accuracy =    26.80%
# 13:34:01 :    iteration =  200, loss =   1.9194, accuracy =    27.30%
# 13:34:12 :    iteration =  300, loss =   2.0080, accuracy =    25.90%
# 13:34:23 :    iteration =  400, loss =   2.0768, accuracy =    27.10%
# 13:34:35 :    iteration =  500, loss =   2.0727, accuracy =    25.80%
# 13:34:46 :    iteration =  600, loss =   2.0032, accuracy =    26.40%
# 13:34:57 :    iteration =  700, loss =   2.1325, accuracy =    26.70%
# 13:35:04 : epoch   41 took 87.11s
# 13:35:04 : epoch   42/ 100
# 13:35:05 :    iteration =    0, loss =   2.0256, accuracy =    26.30%
# 13:35:16 :    iteration =  100, loss =   2.0351, accuracy =    27.00%
# 13:35:28 :    iteration =  200, loss =   1.9184, accuracy =    27.30%
# 13:35:39 :    iteration =  300, loss =   2.0070, accuracy =    26.20%
# 13:35:50 :    iteration =  400, loss =   2.0761, accuracy =    26.80%
# 13:36:01 :    iteration =  500, loss =   2.0723, accuracy =    25.80%
# 13:36:13 :    iteration =  600, loss =   2.0021, accuracy =    26.40%
# 13:36:24 :    iteration =  700, loss =   2.1314, accuracy =    26.90%
# 13:36:31 : epoch   42 took 86.56s
# 13:36:31 : epoch   43/ 100
# 13:36:32 :    iteration =    0, loss =   2.0240, accuracy =    26.10%
# 13:36:43 :    iteration =  100, loss =   2.0332, accuracy =    26.70%
# 13:36:54 :    iteration =  200, loss =   1.9175, accuracy =    27.50%
# 13:37:05 :    iteration =  300, loss =   2.0062, accuracy =    26.10%
# 13:37:17 :    iteration =  400, loss =   2.0755, accuracy =    26.50%
# 13:37:28 :    iteration =  500, loss =   2.0720, accuracy =    26.00%
# 13:37:39 :    iteration =  600, loss =   2.0007, accuracy =    26.40%
# 13:37:50 :    iteration =  700, loss =   2.1302, accuracy =    27.00%
# 13:37:57 : epoch   43 took 86.36s
# 13:37:57 : epoch   44/ 100
# 13:37:58 :    iteration =    0, loss =   2.0226, accuracy =    26.20%
# 13:38:09 :    iteration =  100, loss =   2.0316, accuracy =    26.80%
# 13:38:20 :    iteration =  200, loss =   1.9164, accuracy =    27.60%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 13:38:20 : Current_Best_Acc:  27.6
# 13:38:32 :    iteration =  300, loss =   2.0052, accuracy =    26.30%
# 13:38:43 :    iteration =  400, loss =   2.0748, accuracy =    26.70%
# 13:38:54 :    iteration =  500, loss =   2.0716, accuracy =    26.10%
# 13:39:05 :    iteration =  600, loss =   1.9994, accuracy =    26.50%
# 13:39:16 :    iteration =  700, loss =   2.1292, accuracy =    26.90%
# 13:39:23 : epoch   44 took 86.17s
# 13:39:23 : epoch   45/ 100
# 13:39:24 :    iteration =    0, loss =   2.0210, accuracy =    26.10%
# 13:39:35 :    iteration =  100, loss =   2.0299, accuracy =    27.00%
# 13:39:47 :    iteration =  200, loss =   1.9156, accuracy =    27.80%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 13:39:47 : Current_Best_Acc:  27.800000000000004
# 13:39:58 :    iteration =  300, loss =   2.0043, accuracy =    26.60%
# 13:40:09 :    iteration =  400, loss =   2.0741, accuracy =    26.80%
# 13:40:20 :    iteration =  500, loss =   2.0712, accuracy =    26.20%
# 13:40:31 :    iteration =  600, loss =   1.9980, accuracy =    26.60%
# 13:40:43 :    iteration =  700, loss =   2.1283, accuracy =    26.90%
# 13:40:49 : epoch   45 took 86.18s
# 13:40:49 : epoch   46/ 100
# 13:40:50 :    iteration =    0, loss =   2.0193, accuracy =    26.30%
# 13:41:01 :    iteration =  100, loss =   2.0283, accuracy =    27.30%
# 13:41:13 :    iteration =  200, loss =   1.9146, accuracy =    27.60%
# 13:41:24 :    iteration =  300, loss =   2.0034, accuracy =    26.70%
# 13:41:35 :    iteration =  400, loss =   2.0734, accuracy =    26.90%
# 13:41:46 :    iteration =  500, loss =   2.0709, accuracy =    26.30%
# 13:41:58 :    iteration =  600, loss =   1.9966, accuracy =    26.80%
# 13:42:09 :    iteration =  700, loss =   2.1275, accuracy =    26.90%
# 13:42:16 : epoch   46 took 86.16s
# 13:42:16 : epoch   47/ 100
# 13:42:16 :    iteration =    0, loss =   2.0177, accuracy =    26.30%
# 13:42:28 :    iteration =  100, loss =   2.0266, accuracy =    27.40%
# 13:42:39 :    iteration =  200, loss =   1.9135, accuracy =    27.60%
# 13:42:50 :    iteration =  300, loss =   2.0023, accuracy =    26.50%
# 13:43:01 :    iteration =  400, loss =   2.0728, accuracy =    26.90%
# 13:43:12 :    iteration =  500, loss =   2.0708, accuracy =    26.30%
# 13:43:24 :    iteration =  600, loss =   1.9954, accuracy =    26.80%
# 13:43:35 :    iteration =  700, loss =   2.1266, accuracy =    26.90%
# 13:43:42 : epoch   47 took 86.09s
# 13:43:42 : epoch   48/ 100
# 13:43:42 :    iteration =    0, loss =   2.0164, accuracy =    26.40%
# 13:43:54 :    iteration =  100, loss =   2.0250, accuracy =    27.50%
# 13:44:05 :    iteration =  200, loss =   1.9123, accuracy =    27.70%
# 13:44:16 :    iteration =  300, loss =   2.0013, accuracy =    26.50%
# 13:44:27 :    iteration =  400, loss =   2.0722, accuracy =    27.00%
# 13:44:39 :    iteration =  500, loss =   2.0703, accuracy =    26.30%
# 13:44:50 :    iteration =  600, loss =   1.9942, accuracy =    27.10%
# 13:45:01 :    iteration =  700, loss =   2.1257, accuracy =    27.00%
# 13:45:08 : epoch   48 took 86.10s
# 13:45:08 : epoch   49/ 100
# 13:45:09 :    iteration =    0, loss =   2.0151, accuracy =    26.50%
# 13:45:20 :    iteration =  100, loss =   2.0235, accuracy =    27.50%
# 13:45:31 :    iteration =  200, loss =   1.9110, accuracy =    27.80%
# 13:45:42 :    iteration =  300, loss =   2.0002, accuracy =    26.60%
# 13:45:54 :    iteration =  400, loss =   2.0718, accuracy =    27.20%
# 13:46:05 :    iteration =  500, loss =   2.0699, accuracy =    26.50%
# 13:46:16 :    iteration =  600, loss =   1.9930, accuracy =    27.10%
# 13:46:27 :    iteration =  700, loss =   2.1248, accuracy =    26.80%
# 13:46:34 : epoch   49 took 86.49s
# 13:46:34 : epoch   50/ 100
# 13:46:35 :    iteration =    0, loss =   2.0134, accuracy =    26.60%
# 13:46:46 :    iteration =  100, loss =   2.0219, accuracy =    27.40%
# 13:46:58 :    iteration =  200, loss =   1.9098, accuracy =    27.90%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 13:46:58 : Current_Best_Acc:  27.900000000000002
# 13:47:09 :    iteration =  300, loss =   1.9992, accuracy =    26.50%
# 13:47:20 :    iteration =  400, loss =   2.0711, accuracy =    27.20%
# 13:47:31 :    iteration =  500, loss =   2.0696, accuracy =    26.60%
# 13:47:42 :    iteration =  600, loss =   1.9917, accuracy =    27.10%
# 13:47:54 :    iteration =  700, loss =   2.1240, accuracy =    26.80%
# 13:48:00 : epoch   50 took 86.15s
# 13:48:00 : epoch   51/ 100
# 13:48:01 :    iteration =    0, loss =   2.0119, accuracy =    26.40%
# 13:48:12 :    iteration =  100, loss =   2.0204, accuracy =    27.60%
# 13:48:24 :    iteration =  200, loss =   1.9090, accuracy =    27.90%
# 13:48:35 :    iteration =  300, loss =   1.9983, accuracy =    26.50%
# 13:48:46 :    iteration =  400, loss =   2.0705, accuracy =    27.00%
# 13:48:57 :    iteration =  500, loss =   2.0694, accuracy =    26.60%
# 13:49:09 :    iteration =  600, loss =   1.9904, accuracy =    27.10%
# 13:49:20 :    iteration =  700, loss =   2.1229, accuracy =    26.90%
# 13:49:27 : epoch   51 took 86.24s
# 13:49:27 : epoch   52/ 100
# 13:49:27 :    iteration =    0, loss =   2.0102, accuracy =    26.40%
# 13:49:39 :    iteration =  100, loss =   2.0189, accuracy =    27.60%
# 13:49:50 :    iteration =  200, loss =   1.9078, accuracy =    27.90%
# 13:50:01 :    iteration =  300, loss =   1.9976, accuracy =    26.60%
# 13:50:12 :    iteration =  400, loss =   2.0701, accuracy =    26.90%
# 13:50:24 :    iteration =  500, loss =   2.0694, accuracy =    26.80%
# 13:50:35 :    iteration =  600, loss =   1.9892, accuracy =    27.10%
# 13:50:46 :    iteration =  700, loss =   2.1217, accuracy =    26.80%
# 13:50:53 : epoch   52 took 86.06s
# 13:50:53 : epoch   53/ 100
# 13:50:54 :    iteration =    0, loss =   2.0087, accuracy =    26.60%
# 13:51:05 :    iteration =  100, loss =   2.0173, accuracy =    27.50%
# 13:51:16 :    iteration =  200, loss =   1.9067, accuracy =    28.10%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 13:51:16 : Current_Best_Acc:  28.1
# 13:51:27 :    iteration =  300, loss =   1.9967, accuracy =    26.50%
# 13:51:38 :    iteration =  400, loss =   2.0697, accuracy =    27.10%
# 13:51:50 :    iteration =  500, loss =   2.0693, accuracy =    27.00%
# 13:52:01 :    iteration =  600, loss =   1.9883, accuracy =    27.10%
# 13:52:12 :    iteration =  700, loss =   2.1206, accuracy =    26.90%
# 13:52:19 : epoch   53 took 86.18s
# 13:52:19 : epoch   54/ 100
# 13:52:20 :    iteration =    0, loss =   2.0071, accuracy =    26.70%
# 13:52:31 :    iteration =  100, loss =   2.0159, accuracy =    27.30%
# 13:52:42 :    iteration =  200, loss =   1.9059, accuracy =    27.80%
# 13:52:54 :    iteration =  300, loss =   1.9959, accuracy =    26.90%
# 13:53:07 :    iteration =  400, loss =   2.0694, accuracy =    27.10%
# 13:53:22 :    iteration =  500, loss =   2.0690, accuracy =    27.30%
# 13:53:36 :    iteration =  600, loss =   1.9874, accuracy =    27.10%
# 13:53:49 :    iteration =  700, loss =   2.1196, accuracy =    26.70%
# 13:53:56 : epoch   54 took 96.88s
# 13:53:56 : epoch   55/ 100
# 13:53:57 :    iteration =    0, loss =   2.0055, accuracy =    27.10%
# 13:54:09 :    iteration =  100, loss =   2.0143, accuracy =    27.40%
# 13:54:21 :    iteration =  200, loss =   1.9048, accuracy =    27.80%
# 13:54:33 :    iteration =  300, loss =   1.9948, accuracy =    26.90%
# 13:54:45 :    iteration =  400, loss =   2.0689, accuracy =    27.10%
# 13:54:57 :    iteration =  500, loss =   2.0686, accuracy =    27.30%
# 13:55:09 :    iteration =  600, loss =   1.9863, accuracy =    27.20%
# 13:55:20 :    iteration =  700, loss =   2.1188, accuracy =    26.70%
# 13:55:28 : epoch   55 took 91.68s
# 13:55:28 : epoch   56/ 100
# 13:55:28 :    iteration =    0, loss =   2.0039, accuracy =    27.00%
# 13:55:40 :    iteration =  100, loss =   2.0129, accuracy =    27.30%
# 13:55:52 :    iteration =  200, loss =   1.9038, accuracy =    27.80%
# 13:56:05 :    iteration =  300, loss =   1.9940, accuracy =    26.90%
# 13:56:18 :    iteration =  400, loss =   2.0686, accuracy =    27.10%
# 13:56:30 :    iteration =  500, loss =   2.0683, accuracy =    27.20%
# 13:56:42 :    iteration =  600, loss =   1.9850, accuracy =    27.50%
# 13:56:54 :    iteration =  700, loss =   2.1180, accuracy =    26.90%
# 13:57:02 : epoch   56 took 94.19s
# 13:57:02 : epoch   57/ 100
# 13:57:03 :    iteration =    0, loss =   2.0024, accuracy =    27.00%
# 13:57:15 :    iteration =  100, loss =   2.0116, accuracy =    27.30%
# 13:57:27 :    iteration =  200, loss =   1.9028, accuracy =    28.10%
# 13:57:39 :    iteration =  300, loss =   1.9932, accuracy =    27.10%
# 13:57:51 :    iteration =  400, loss =   2.0684, accuracy =    27.40%
# 13:58:03 :    iteration =  500, loss =   2.0680, accuracy =    27.30%
# 13:58:15 :    iteration =  600, loss =   1.9837, accuracy =    27.70%
# 13:58:27 :    iteration =  700, loss =   2.1170, accuracy =    26.80%
# 13:58:34 : epoch   57 took 92.54s
# 13:58:34 : epoch   58/ 100
# 13:58:35 :    iteration =    0, loss =   2.0010, accuracy =    27.40%
# 13:58:48 :    iteration =  100, loss =   2.0103, accuracy =    27.50%
# 13:59:01 :    iteration =  200, loss =   1.9019, accuracy =    28.30%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 13:59:01 : Current_Best_Acc:  28.299999999999997
# 13:59:14 :    iteration =  300, loss =   1.9924, accuracy =    27.00%
# 13:59:26 :    iteration =  400, loss =   2.0677, accuracy =    27.30%
# 13:59:38 :    iteration =  500, loss =   2.0679, accuracy =    27.40%
# 13:59:50 :    iteration =  600, loss =   1.9826, accuracy =    27.90%
# 14:00:01 :    iteration =  700, loss =   2.1162, accuracy =    27.00%
# 14:00:09 : epoch   58 took 95.21s
# 14:00:09 : epoch   59/ 100
# 14:00:10 :    iteration =    0, loss =   1.9996, accuracy =    27.40%
# 14:00:25 :    iteration =  100, loss =   2.0090, accuracy =    27.50%
# 14:00:37 :    iteration =  200, loss =   1.9010, accuracy =    28.30%
# 14:00:49 :    iteration =  300, loss =   1.9918, accuracy =    27.30%
# 14:01:00 :    iteration =  400, loss =   2.0673, accuracy =    27.40%
# 14:01:11 :    iteration =  500, loss =   2.0678, accuracy =    27.40%
# 14:01:23 :    iteration =  600, loss =   1.9816, accuracy =    27.90%
# 14:01:34 :    iteration =  700, loss =   2.1153, accuracy =    27.30%
# 14:01:41 : epoch   59 took 91.30s
# 14:01:41 : epoch   60/ 100
# 14:01:41 :    iteration =    0, loss =   1.9982, accuracy =    27.50%
# 14:01:53 :    iteration =  100, loss =   2.0078, accuracy =    27.70%
# 14:02:04 :    iteration =  200, loss =   1.9002, accuracy =    28.30%
# 14:02:16 :    iteration =  300, loss =   1.9912, accuracy =    27.30%
# 14:02:27 :    iteration =  400, loss =   2.0668, accuracy =    27.40%
# 14:02:38 :    iteration =  500, loss =   2.0677, accuracy =    27.50%
# 14:02:49 :    iteration =  600, loss =   1.9806, accuracy =    28.40%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 14:02:49 : Current_Best_Acc:  28.4
# 14:03:01 :    iteration =  700, loss =   2.1146, accuracy =    27.20%
# 14:03:07 : epoch   60 took 86.60s
# 14:03:07 : epoch   61/ 100
# 14:03:08 :    iteration =    0, loss =   1.9968, accuracy =    27.90%
# 14:03:19 :    iteration =  100, loss =   2.0067, accuracy =    27.60%
# 14:03:31 :    iteration =  200, loss =   1.8993, accuracy =    28.30%
# 14:03:42 :    iteration =  300, loss =   1.9907, accuracy =    27.10%
# 14:03:54 :    iteration =  400, loss =   2.0664, accuracy =    27.70%
# 14:04:05 :    iteration =  500, loss =   2.0677, accuracy =    27.50%
# 14:04:17 :    iteration =  600, loss =   1.9796, accuracy =    28.40%
# 14:04:29 :    iteration =  700, loss =   2.1137, accuracy =    27.70%
# 14:04:36 : epoch   61 took 88.23s
# 14:04:36 : epoch   62/ 100
# 14:04:36 :    iteration =    0, loss =   1.9956, accuracy =    27.90%
# 14:04:48 :    iteration =  100, loss =   2.0057, accuracy =    27.80%
# 14:04:59 :    iteration =  200, loss =   1.8987, accuracy =    28.60%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 14:04:59 : Current_Best_Acc:  28.599999999999998
# 14:05:10 :    iteration =  300, loss =   1.9903, accuracy =    27.10%
# 14:05:21 :    iteration =  400, loss =   2.0659, accuracy =    27.80%
# 14:05:32 :    iteration =  500, loss =   2.0676, accuracy =    27.40%
# 14:05:44 :    iteration =  600, loss =   1.9784, accuracy =    28.50%
# 14:05:55 :    iteration =  700, loss =   2.1129, accuracy =    27.90%
# 14:06:02 : epoch   62 took 86.85s
# 14:06:02 : epoch   63/ 100
# 14:06:03 :    iteration =    0, loss =   1.9942, accuracy =    28.00%
# 14:06:15 :    iteration =  100, loss =   2.0048, accuracy =    27.60%
# 14:06:27 :    iteration =  200, loss =   1.8981, accuracy =    28.70%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 14:06:27 : Current_Best_Acc:  28.7
# 14:06:39 :    iteration =  300, loss =   1.9898, accuracy =    27.40%
# 14:06:52 :    iteration =  400, loss =   2.0653, accuracy =    27.90%
# 14:07:05 :    iteration =  500, loss =   2.0676, accuracy =    27.50%
# 14:07:17 :    iteration =  600, loss =   1.9772, accuracy =    28.60%
# 14:07:28 :    iteration =  700, loss =   2.1119, accuracy =    28.00%
# 14:07:35 : epoch   63 took 92.59s
# 14:07:35 : epoch   64/ 100
# 14:07:36 :    iteration =    0, loss =   1.9928, accuracy =    28.00%
# 14:07:47 :    iteration =  100, loss =   2.0037, accuracy =    27.90%
# 14:07:59 :    iteration =  200, loss =   1.8973, accuracy =    28.70%
# 14:08:10 :    iteration =  300, loss =   1.9894, accuracy =    27.30%
# 14:08:21 :    iteration =  400, loss =   2.0645, accuracy =    28.10%
# 14:08:33 :    iteration =  500, loss =   2.0675, accuracy =    27.60%
# 14:08:44 :    iteration =  600, loss =   1.9760, accuracy =    28.90%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 14:08:44 : Current_Best_Acc:  28.9
# 14:08:56 :    iteration =  700, loss =   2.1111, accuracy =    28.30%
# 14:09:03 : epoch   64 took 87.78s
# 14:09:03 : epoch   65/ 100
# 14:09:04 :    iteration =    0, loss =   1.9913, accuracy =    28.40%
# 14:09:15 :    iteration =  100, loss =   2.0025, accuracy =    27.90%
# 14:09:26 :    iteration =  200, loss =   1.8965, accuracy =    28.70%
# 14:09:38 :    iteration =  300, loss =   1.9892, accuracy =    27.60%
# 14:09:50 :    iteration =  400, loss =   2.0639, accuracy =    28.50%
# 14:10:03 :    iteration =  500, loss =   2.0674, accuracy =    27.50%
# 14:10:15 :    iteration =  600, loss =   1.9748, accuracy =    29.10%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 14:10:15 : Current_Best_Acc:  29.099999999999998
# 14:10:26 :    iteration =  700, loss =   2.1105, accuracy =    28.40%
# 14:10:33 : epoch   65 took 90.33s
# 14:10:33 : epoch   66/ 100
# 14:10:34 :    iteration =    0, loss =   1.9896, accuracy =    28.50%
# 14:10:45 :    iteration =  100, loss =   2.0014, accuracy =    28.30%
# 14:10:56 :    iteration =  200, loss =   1.8957, accuracy =    28.80%
# 14:11:08 :    iteration =  300, loss =   1.9891, accuracy =    27.70%
# 14:11:20 :    iteration =  400, loss =   2.0631, accuracy =    28.50%
# 14:11:33 :    iteration =  500, loss =   2.0674, accuracy =    27.50%
# 14:11:46 :    iteration =  600, loss =   1.9737, accuracy =    29.10%
# ...
# 14:25:51 :    iteration =  200, loss =   1.8891, accuracy =    29.30%
# 14:26:06 :    iteration =  300, loss =   1.9832, accuracy =    28.70%
# 14:26:19 :    iteration =  400, loss =   2.0588, accuracy =    28.70%
# 14:26:32 :    iteration =  500, loss =   2.0663, accuracy =    27.80%
# 14:26:45 :    iteration =  600, loss =   1.9644, accuracy =    29.30%
# 14:26:57 :    iteration =  700, loss =   2.1026, accuracy =    28.80%
# 14:27:04 : epoch   76 took 98.23s
# 14:27:04 : epoch   77/ 100
# 14:27:05 :    iteration =    0, loss =   1.9767, accuracy =    28.90%
# 14:27:16 :    iteration =  100, loss =   1.9897, accuracy =    29.30%
# 14:27:27 :    iteration =  200, loss =   1.8886, accuracy =    29.10%
# 14:27:40 :    iteration =  300, loss =   1.9827, accuracy =    28.50%
# 14:27:52 :    iteration =  400, loss =   2.0586, accuracy =    28.90%
# 14:28:04 :    iteration =  500, loss =   2.0661, accuracy =    27.80%
# 14:28:16 :    iteration =  600, loss =   1.9635, accuracy =    29.30%
# 14:28:27 :    iteration =  700, loss =   2.1020, accuracy =    28.80%
# 14:28:35 : epoch   77 took 91.31s
# 14:28:35 : epoch   78/ 100
# 14:28:36 :    iteration =    0, loss =   1.9755, accuracy =    28.90%
# 14:28:49 :    iteration =  100, loss =   1.9886, accuracy =    29.30%
# 14:29:00 :    iteration =  200, loss =   1.8882, accuracy =    29.40%
# 14:29:12 :    iteration =  300, loss =   1.9823, accuracy =    28.50%
# 14:29:23 :    iteration =  400, loss =   2.0583, accuracy =    28.80%
# 14:29:34 :    iteration =  500, loss =   2.0662, accuracy =    27.80%
# 14:29:46 :    iteration =  600, loss =   1.9627, accuracy =    29.30%
# 14:29:57 :    iteration =  700, loss =   2.1013, accuracy =    29.00%
# 14:30:04 : epoch   78 took 89.19s
# 14:30:04 : epoch   79/ 100
# 14:30:05 :    iteration =    0, loss =   1.9741, accuracy =    29.00%
# 14:30:16 :    iteration =  100, loss =   1.9874, accuracy =    29.40%
# 14:30:28 :    iteration =  200, loss =   1.8875, accuracy =    29.50%
# 14:30:39 :    iteration =  300, loss =   1.9820, accuracy =    28.50%
# 14:30:51 :    iteration =  400, loss =   2.0579, accuracy =    28.90%
# 14:31:02 :    iteration =  500, loss =   2.0662, accuracy =    28.00%
# 14:31:14 :    iteration =  600, loss =   1.9621, accuracy =    29.30%
# 14:31:25 :    iteration =  700, loss =   2.1007, accuracy =    29.00%
# 14:31:32 : epoch   79 took 88.12s
# 14:31:32 : epoch   80/ 100
# 14:31:33 :    iteration =    0, loss =   1.9730, accuracy =    28.80%
# 14:31:45 :    iteration =  100, loss =   1.9863, accuracy =    29.30%
# 14:31:56 :    iteration =  200, loss =   1.8871, accuracy =    29.60%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 14:31:56 : Current_Best_Acc:  29.599999999999998
# 14:32:07 :    iteration =  300, loss =   1.9813, accuracy =    28.60%
# 14:32:19 :    iteration =  400, loss =   2.0574, accuracy =    28.90%
# 14:32:31 :    iteration =  500, loss =   2.0663, accuracy =    28.10%
# 14:32:42 :    iteration =  600, loss =   1.9615, accuracy =    29.40%
# 14:32:54 :    iteration =  700, loss =   2.0999, accuracy =    29.10%
# 14:33:01 : epoch   80 took 88.27s
# 14:33:01 : epoch   81/ 100
# 14:33:01 :    iteration =    0, loss =   1.9717, accuracy =    28.70%
# 14:33:13 :    iteration =  100, loss =   1.9852, accuracy =    29.30%
# 14:33:24 :    iteration =  200, loss =   1.8864, accuracy =    29.70%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 14:33:24 : Current_Best_Acc:  29.7
# 14:33:36 :    iteration =  300, loss =   1.9807, accuracy =    28.60%
# 14:33:47 :    iteration =  400, loss =   2.0571, accuracy =    28.80%
# 14:33:59 :    iteration =  500, loss =   2.0659, accuracy =    28.30%
# 14:34:10 :    iteration =  600, loss =   1.9608, accuracy =    29.50%
# 14:34:22 :    iteration =  700, loss =   2.0992, accuracy =    29.10%
# 14:34:29 : epoch   81 took 88.06s
# 14:34:29 : epoch   82/ 100
# 14:34:30 :    iteration =    0, loss =   1.9706, accuracy =    28.90%
# 14:34:41 :    iteration =  100, loss =   1.9842, accuracy =    29.30%
# 14:34:52 :    iteration =  200, loss =   1.8856, accuracy =    29.80%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 14:34:52 : Current_Best_Acc:  29.799999999999997
# 14:35:04 :    iteration =  300, loss =   1.9801, accuracy =    28.40%
# 14:35:16 :    iteration =  400, loss =   2.0566, accuracy =    28.70%
# 14:35:29 :    iteration =  500, loss =   2.0658, accuracy =    28.10%
# 14:35:40 :    iteration =  600, loss =   1.9600, accuracy =    29.40%
# 14:35:52 :    iteration =  700, loss =   2.0984, accuracy =    29.30%
# 14:35:59 : epoch   82 took 90.11s
# 14:35:59 : epoch   83/ 100
# 14:36:00 :    iteration =    0, loss =   1.9694, accuracy =    28.90%
# 14:36:13 :    iteration =  100, loss =   1.9832, accuracy =    29.50%
# 14:36:25 :    iteration =  200, loss =   1.8848, accuracy =    29.60%
# 14:36:36 :    iteration =  300, loss =   1.9797, accuracy =    28.50%
# 14:36:48 :    iteration =  400, loss =   2.0562, accuracy =    28.50%
# 14:36:59 :    iteration =  500, loss =   2.0655, accuracy =    28.40%
# 14:37:11 :    iteration =  600, loss =   1.9593, accuracy =    29.60%
# 14:37:22 :    iteration =  700, loss =   2.0976, accuracy =    29.70%
# 14:37:29 : epoch   83 took 90.31s
# 14:37:29 : epoch   84/ 100
# 14:37:30 :    iteration =    0, loss =   1.9682, accuracy =    29.00%
# 14:37:41 :    iteration =  100, loss =   1.9822, accuracy =    29.70%
# 14:37:53 :    iteration =  200, loss =   1.8841, accuracy =    29.60%
# 14:38:04 :    iteration =  300, loss =   1.9792, accuracy =    28.50%
# 14:38:16 :    iteration =  400, loss =   2.0557, accuracy =    28.60%
# 14:38:27 :    iteration =  500, loss =   2.0654, accuracy =    28.50%
# 14:38:39 :    iteration =  600, loss =   1.9587, accuracy =    29.50%
# 14:38:50 :    iteration =  700, loss =   2.0968, accuracy =    29.80%
# 14:38:57 : epoch   84 took 87.86s
# 14:38:57 : epoch   85/ 100
# 14:38:58 :    iteration =    0, loss =   1.9669, accuracy =    29.00%
# 14:39:09 :    iteration =  100, loss =   1.9813, accuracy =    29.70%
# 14:39:21 :    iteration =  200, loss =   1.8832, accuracy =    29.70%
# 14:39:32 :    iteration =  300, loss =   1.9787, accuracy =    28.80%
# 14:39:44 :    iteration =  400, loss =   2.0553, accuracy =    28.50%
# 14:39:55 :    iteration =  500, loss =   2.0652, accuracy =    28.60%
# 14:40:06 :    iteration =  600, loss =   1.9580, accuracy =    29.60%
# 14:40:18 :    iteration =  700, loss =   2.0961, accuracy =    29.90%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 14:40:18 : Current_Best_Acc:  29.9
# 14:40:25 : epoch   85 took 88.03s
# 14:40:25 : epoch   86/ 100
# 14:40:26 :    iteration =    0, loss =   1.9656, accuracy =    29.20%
# 14:40:37 :    iteration =  100, loss =   1.9800, accuracy =    29.60%
# 14:40:49 :    iteration =  200, loss =   1.8824, accuracy =    29.60%
# 14:41:00 :    iteration =  300, loss =   1.9783, accuracy =    28.90%
# 14:41:12 :    iteration =  400, loss =   2.0547, accuracy =    28.60%
# 14:41:23 :    iteration =  500, loss =   2.0651, accuracy =    28.80%
# 14:41:34 :    iteration =  600, loss =   1.9575, accuracy =    29.50%
# 14:41:46 :    iteration =  700, loss =   2.0953, accuracy =    29.90%
# 14:41:53 : epoch   86 took 87.90s
# 14:41:53 : epoch   87/ 100
# 14:41:54 :    iteration =    0, loss =   1.9645, accuracy =    29.20%
# 14:42:05 :    iteration =  100, loss =   1.9790, accuracy =    29.50%
# 14:42:17 :    iteration =  200, loss =   1.8817, accuracy =    29.60%
# 14:42:28 :    iteration =  300, loss =   1.9777, accuracy =    29.00%
# 14:42:40 :    iteration =  400, loss =   2.0544, accuracy =    28.60%
# 14:42:51 :    iteration =  500, loss =   2.0649, accuracy =    29.00%
# 14:43:03 :    iteration =  600, loss =   1.9569, accuracy =    29.60%
# 14:43:14 :    iteration =  700, loss =   2.0945, accuracy =    30.00%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 14:43:14 : Current_Best_Acc:  30.0
# 14:43:21 : epoch   87 took 88.07s
# 14:43:21 : epoch   88/ 100
# 14:43:22 :    iteration =    0, loss =   1.9633, accuracy =    29.10%
# 14:43:33 :    iteration =  100, loss =   1.9780, accuracy =    29.50%
# 14:43:45 :    iteration =  200, loss =   1.8809, accuracy =    29.60%
# 14:43:56 :    iteration =  300, loss =   1.9773, accuracy =    28.90%
# 14:44:07 :    iteration =  400, loss =   2.0541, accuracy =    28.70%
# 14:44:19 :    iteration =  500, loss =   2.0648, accuracy =    29.10%
# 14:44:30 :    iteration =  600, loss =   1.9563, accuracy =    29.90%
# 14:44:42 :    iteration =  700, loss =   2.0937, accuracy =    29.90%
# 14:44:49 : epoch   88 took 87.74s
# 14:44:49 : epoch   89/ 100
# 14:44:50 :    iteration =    0, loss =   1.9621, accuracy =    29.20%
# 14:45:01 :    iteration =  100, loss =   1.9770, accuracy =    29.50%
# 14:45:12 :    iteration =  200, loss =   1.8803, accuracy =    29.60%
# 14:45:24 :    iteration =  300, loss =   1.9768, accuracy =    28.90%
# 14:45:35 :    iteration =  400, loss =   2.0537, accuracy =    28.70%
# 14:45:47 :    iteration =  500, loss =   2.0646, accuracy =    29.20%
# 14:45:58 :    iteration =  600, loss =   1.9556, accuracy =    29.90%
# 14:46:10 :    iteration =  700, loss =   2.0929, accuracy =    29.80%
# 14:46:16 : epoch   89 took 87.73s
# 14:46:16 : epoch   90/ 100
# 14:46:17 :    iteration =    0, loss =   1.9608, accuracy =    29.30%
# 14:46:29 :    iteration =  100, loss =   1.9760, accuracy =    29.30%
# 14:46:40 :    iteration =  200, loss =   1.8796, accuracy =    29.60%
# 14:46:52 :    iteration =  300, loss =   1.9763, accuracy =    28.80%
# 14:47:03 :    iteration =  400, loss =   2.0534, accuracy =    28.80%
# 14:47:14 :    iteration =  500, loss =   2.0645, accuracy =    29.20%
# 14:47:26 :    iteration =  600, loss =   1.9550, accuracy =    29.80%
# 14:47:37 :    iteration =  700, loss =   2.0921, accuracy =    29.80%
# 14:47:44 : epoch   90 took 87.80s
# 14:47:44 : epoch   91/ 100
# 14:47:45 :    iteration =    0, loss =   1.9594, accuracy =    29.20%
# 14:47:56 :    iteration =  100, loss =   1.9748, accuracy =    29.30%
# 14:48:08 :    iteration =  200, loss =   1.8788, accuracy =    29.70%
# 14:48:19 :    iteration =  300, loss =   1.9757, accuracy =    29.00%
# 14:48:31 :    iteration =  400, loss =   2.0529, accuracy =    28.80%
# 14:48:42 :    iteration =  500, loss =   2.0641, accuracy =    29.10%
# 14:48:54 :    iteration =  600, loss =   1.9542, accuracy =    29.90%
# 14:49:05 :    iteration =  700, loss =   2.0915, accuracy =    29.80%
# 14:49:12 : epoch   91 took 87.79s
# 14:49:12 : epoch   92/ 100
# 14:49:13 :    iteration =    0, loss =   1.9582, accuracy =    29.20%
# 14:49:24 :    iteration =  100, loss =   1.9737, accuracy =    29.40%
# 14:49:36 :    iteration =  200, loss =   1.8780, accuracy =    29.60%
# 14:49:47 :    iteration =  300, loss =   1.9753, accuracy =    29.10%
# 14:49:59 :    iteration =  400, loss =   2.0525, accuracy =    28.80%
# 14:50:10 :    iteration =  500, loss =   2.0640, accuracy =    29.10%
# 14:50:21 :    iteration =  600, loss =   1.9534, accuracy =    30.30%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 14:50:21 : Current_Best_Acc:  30.3
# 14:50:33 :    iteration =  700, loss =   2.0908, accuracy =    30.10%
# 14:50:40 : epoch   92 took 87.83s
# 14:50:40 : epoch   93/ 100
# 14:50:41 :    iteration =    0, loss =   1.9571, accuracy =    29.20%
# 14:50:52 :    iteration =  100, loss =   1.9725, accuracy =    29.60%
# 14:51:04 :    iteration =  200, loss =   1.8772, accuracy =    29.70%
# 14:51:15 :    iteration =  300, loss =   1.9746, accuracy =    29.10%
# 14:51:26 :    iteration =  400, loss =   2.0522, accuracy =    28.80%
# 14:51:38 :    iteration =  500, loss =   2.0640, accuracy =    29.00%
# 14:51:49 :    iteration =  600, loss =   1.9528, accuracy =    30.30%
# 14:52:01 :    iteration =  700, loss =   2.0902, accuracy =    30.20%
# 14:52:08 : epoch   93 took 87.74s
# 14:52:08 : epoch   94/ 100
# 14:52:08 :    iteration =    0, loss =   1.9560, accuracy =    29.40%
# 14:52:20 :    iteration =  100, loss =   1.9715, accuracy =    29.60%
# 14:52:31 :    iteration =  200, loss =   1.8764, accuracy =    29.70%
# 14:52:43 :    iteration =  300, loss =   1.9741, accuracy =    29.20%
# 14:52:54 :    iteration =  400, loss =   2.0515, accuracy =    28.90%
# 14:53:06 :    iteration =  500, loss =   2.0638, accuracy =    28.90%
# 14:53:17 :    iteration =  600, loss =   1.9522, accuracy =    30.30%
# 14:53:29 :    iteration =  700, loss =   2.0896, accuracy =    30.20%
# 14:53:36 : epoch   94 took 87.89s
# 14:53:36 : epoch   95/ 100
# 14:53:36 :    iteration =    0, loss =   1.9548, accuracy =    29.60%
# 14:53:48 :    iteration =  100, loss =   1.9703, accuracy =    29.50%
# 14:53:59 :    iteration =  200, loss =   1.8758, accuracy =    29.90%
# 14:54:11 :    iteration =  300, loss =   1.9734, accuracy =    29.10%
# 14:54:22 :    iteration =  400, loss =   2.0510, accuracy =    28.90%
# 14:54:34 :    iteration =  500, loss =   2.0638, accuracy =    28.70%
# 14:54:45 :    iteration =  600, loss =   1.9516, accuracy =    30.20%
# 14:54:56 :    iteration =  700, loss =   2.0888, accuracy =    30.10%
# 14:55:03 : epoch   95 took 87.86s
# 14:55:03 : epoch   96/ 100
# 14:55:04 :    iteration =    0, loss =   1.9538, accuracy =    29.60%
# 14:55:16 :    iteration =  100, loss =   1.9694, accuracy =    29.50%
# 14:55:27 :    iteration =  200, loss =   1.8756, accuracy =    30.00%
# 14:55:38 :    iteration =  300, loss =   1.9727, accuracy =    29.10%
# 14:55:50 :    iteration =  400, loss =   2.0505, accuracy =    28.90%
# 14:56:01 :    iteration =  500, loss =   2.0636, accuracy =    28.70%
# 14:56:13 :    iteration =  600, loss =   1.9508, accuracy =    30.30%
# 14:56:24 :    iteration =  700, loss =   2.0883, accuracy =    30.10%
# 14:56:31 : epoch   96 took 87.69s
# 14:56:31 : epoch   97/ 100
# 14:56:32 :    iteration =    0, loss =   1.9529, accuracy =    29.60%
# 14:56:43 :    iteration =  100, loss =   1.9683, accuracy =    29.60%
# 14:56:55 :    iteration =  200, loss =   1.8749, accuracy =    30.20%
# 14:57:06 :    iteration =  300, loss =   1.9722, accuracy =    29.20%
# 14:57:18 :    iteration =  400, loss =   2.0501, accuracy =    28.90%
# 14:57:29 :    iteration =  500, loss =   2.0636, accuracy =    28.70%
# 14:57:40 :    iteration =  600, loss =   1.9502, accuracy =    30.40%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 14:57:40 : Current_Best_Acc:  30.4
# 14:57:52 :    iteration =  700, loss =   2.0878, accuracy =    30.10%
# 14:57:59 : epoch   97 took 87.69s
# 14:57:59 : epoch   98/ 100
# 14:58:00 :    iteration =    0, loss =   1.9518, accuracy =    29.70%
# 14:58:11 :    iteration =  100, loss =   1.9674, accuracy =    29.70%
# 14:58:23 :    iteration =  200, loss =   1.8742, accuracy =    30.20%
# 14:58:34 :    iteration =  300, loss =   1.9716, accuracy =    29.30%
# 14:58:45 :    iteration =  400, loss =   2.0496, accuracy =    28.90%
# 14:58:57 :    iteration =  500, loss =   2.0635, accuracy =    28.70%
# 14:59:08 :    iteration =  600, loss =   1.9495, accuracy =    30.70%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 14:59:08 : Current_Best_Acc:  30.7
# 14:59:20 :    iteration =  700, loss =   2.0871, accuracy =    30.10%
# 14:59:27 : epoch   98 took 87.96s
# 14:59:27 : epoch   99/ 100
# 14:59:27 :    iteration =    0, loss =   1.9508, accuracy =    29.70%
# 14:59:39 :    iteration =  100, loss =   1.9664, accuracy =    29.60%
# 14:59:50 :    iteration =  200, loss =   1.8733, accuracy =    30.20%
# 15:00:02 :    iteration =  300, loss =   1.9711, accuracy =    29.30%
# 15:00:13 :    iteration =  400, loss =   2.0491, accuracy =    29.00%
# 15:00:25 :    iteration =  500, loss =   2.0632, accuracy =    28.80%
# 15:00:36 :    iteration =  600, loss =   1.9488, accuracy =    30.80%
# Model saved in path: E:\courses\stat231A\homework1\models\best_model_block1_and_block2.ckpt
# 15:00:36 : Current_Best_Acc:  30.8
# 15:00:48 :    iteration =  700, loss =   2.0865, accuracy =    30.10%
# 15:00:55 : epoch   99 took 88.11s
# 15:00:55 : Finished training

# %%
print(train_losses)
print(test_accuracies)
# Out:
# [2.8028224, 2.498616, 2.3845265, 2.3270955, 2.292948, 2.26975, 2.2538009, 2.2421422, 2.233581, 2.2265036, 2.2195644, 2.2137423, 2.2086108, 2.2045758, 2.2013564, 2.1990685, 2.1968646, 2.1945095, 2.1925101, 2.190737, 2.188683, 2.1867652, 2.1850266, 2.1835935, 2.1820512, 2.1805875, 2.1791337, 2.1774926, 2.1761894, 2.174725, 2.1734984, 2.1721241, 2.1705844, 2.1691709, 2.1676197, 2.166097, 2.1647027, 2.163298, 2.1618605, 2.1603649, 2.1588771, 2.157621, 2.1562989, 2.1550128, 2.1536174, 2.1522708, 2.1508632, 2.149453, 2.1482677, 2.1471498, 2.1460822, 2.1449642, 2.1440048, 2.142964, 2.1417751, 2.1408324, 2.1398742, 2.1388, 2.1376953, 2.136705, 2.1355996, 2.1346817, 2.1337733, 2.1329713, 2.1321661, 2.131213, 2.1302238, 2.1294315, 2.128615, 2.1277387, 2.1268036, 2.1257877, 2.1247969, 2.1238341, 2.1230273, 2.1220298, 2.1210608, 2.1202438, 2.119468, 2.118433, 2.117371, 2.1166139, 2.1158073, 2.1150608, 2.1143858, 2.1136832, 2.1128745, 2.112221, 2.1114528, 2.1107767, 2.1102188, 2.1098492, 2.1095133, 2.109073, 2.1087413, 2.108263, 2.1076453, 2.1072361, 2.1069522, 2.1066043]
# [15.4, 18.3, 19.0, 19.6, 19.900000000000002, 21.099999999999998, 21.2, 21.9, 22.1, 22.0, 22.6, 23.400000000000002, 23.200000000000003, 23.599999999999998, 24.099999999999998, 24.6, 24.8, 24.7, 24.9, 25.4, 25.7, 25.8, 25.8, 25.900000000000002, 25.8, 25.8, 25.900000000000002, 25.7, 25.7, 25.900000000000002, 26.200000000000003, 26.400000000000002, 26.6, 26.700000000000003, 26.700000000000003, 26.700000000000003, 26.8, 26.6, 26.700000000000003, 26.8, 26.8, 26.700000000000003, 26.900000000000002, 27.0, 26.900000000000002, 26.900000000000002, 26.900000000000002, 26.900000000000002, 27.0, 26.8, 26.8, 26.900000000000002, 26.8, 26.900000000000002, 26.700000000000003, 26.700000000000003, 26.900000000000002, 26.8, 27.0, 27.3, 27.200000000000003, 27.700000000000003, 27.900000000000002, 28.000000000000004, 28.299999999999997, 28.4, 28.599999999999998, 28.499999999999996, 28.599999999999998, 28.7, 28.799999999999997, 28.799999999999997, 28.799999999999997, 28.799999999999997, 28.799999999999997, 28.799999999999997, 28.799999999999997, 28.799999999999997, 28.999999999999996, 28.999999999999996, 29.099999999999998, 29.099999999999998, 29.299999999999997, 29.7, 29.799999999999997, 29.9, 29.9, 30.0, 29.9, 29.799999999999997, 29.799999999999997, 29.799999999999997, 30.099999999999998, 30.2, 30.2, 30.099999999999998, 30.099999999999998, 30.099999999999998, 30.099999999999998, 30.099999999999998]

# %%
train_writer = tf.summary.FileWriter('E:\\courses\\stat231A\\homework1\\models\\',
                                      sess.graph)

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.io import export_png

# %%
# prepare some data
x = train_losses
y = test_accuracies

# create a new plot with a title and axis labels
p = figure(title="Training Loss over Epochs", x_axis_label='epoch', y_axis_label='training loss')

# add a line renderer with legend and line thickness
p.line(np.arange(len(x)), x, line_width=2)

# create a new plot with a title and axis labels
q = figure(title="Testing Accuracy over Epochs", x_axis_label='epoch', y_axis_label='accuracy')

# add a line renderer with legend and line thickness
q.line(np.arange(len(y)), y, line_width=2)

#show
output_notebook()
show(p)
show(q)

# %%
params_block1_only, params_val_block1_only, train_losses_block1_only, test_accuracies_block1_only \
= train(convnet_forward_block1_only, convnet_init_block1_only, learning_rate, epochs=epochs)

# %%
params_block1_and_block2, params_val_block1_and_block2, train_losses_block1_and_block2, test_accuracies_block1_and_block2 \
= train(convnet_forward_block1_and_block2, convnet_init_block1_and_block2, learning_rate, epochs=epochs)

# %%
params_block1_block2_and_block3, params_val_block1_block2_and_block3, train_losses_block1_block2_and_block3, test_accuracies_block1_block2_and_block3 \
= train(convnet_forward_block1_block2_and_block3, convnet_init_block1_block2_and_block3, learning_rate, epochs=epochs)

# %%
def plot_kernels_on_grid(kernel, grid_Y, grid_X, pad = 1):
    """
    Visualize convolutional features as an image.

    Args:
      kernel:            tensor of shape [Y, X, NumChannels, NumKernels]
      (grid_Y, grid_X):  shape of the grid. Require: NumKernels == grid_Y * grid_X
                           User is responsible of how to break into two multiples.
      pad:               number of black pixels around each filter (between them)

    Return:
      Tensor of shape [(Y+2*pad)*grid_Y, (X+2*pad)*grid_X, NumChannels, 1].
    """

    x_min = tf.reduce_min(kernel)
    x_max = tf.reduce_max(kernel)

    kernel1 = (kernel - x_min) / (x_max - x_min)

    # pad X and Y
    x1 = tf.pad(kernel1, tf.constant([[pad,pad], [pad, pad], [0,0], [0,0]]), mode='CONSTANT')

    # X and Y dimensions, w.r.t. padding
    Y = kernel1.get_shape()[0] + 2 * pad
    X = kernel1.get_shape()[1] + 2 * pad

    channels = kernel1.get_shape()[2]

    # put NumKernels to the 1st dimension
    x2 = tf.transpose(x1, (3, 0, 1, 2))
    # organize grid on Y axis
    x3 = tf.reshape(x2, tf.stack([grid_X, Y * grid_Y, X, channels]))

    # switch X and Y axes
    x4 = tf.transpose(x3, (0, 2, 1, 3))
    # organize grid on X axis
    x5 = tf.reshape(x4, tf.stack([1, X * grid_X, Y * grid_Y, channels]))

    # back to normal order (not combining with the next step for clarity)
    x6 = tf.transpose(x5, (2, 1, 3, 0))

    # to tf.image_summary order [batch_size, height, width, channels], where in this case batch_size == 1
    x7 = tf.transpose(x6, (3, 0, 1, 2))

    # scale to [0, 255] and convert to uint8
    return tf.image.convert_image_dtype(x7, dtype=tf.uint8)


grid = plot_kernels_on_grid(params_val[0], 4, 8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-148897cd5918> in <module>()
#      47
#      48
# ---> 49 grid = plot_kernels_on_grid(params_val[0], 4, 8)
#
# NameError: name 'params_val' is not defined

# %%
saver = tf.train.Saver()
with tf.Session() as sess:
    ############################################################################
    # TODO: Retrieve image of kernels from symbolic 'grid' variable.           #
    ############################################################################
    saver.restore(sess, "E:\\courses\\stat231A\\homework1\\models\\final_model.ckpt")
    grid_val = sess.run(grid)

    ############################################################################
    #                             END OF YOUR CODE                             #
    ############################################################################
    plt.imshow(grid_val[0])
    plt.show()
    img = Image.fromarray(grid_val[0], 'RGB')
    img.save('3_kernels.jpeg')

# %%
params_val[0].shape

# %%
def plot_filter_grid(units):
    filters = units.shape[3]
    plt.figure(1, figsize=(20, 12))
    n_columns = 8
    n_rows = math.ceil(filters / n_columns) + 1
    for i in range(filters):
        plt.subplot(n_rows, n_columns, i+1)
        plt.title('Filter ' + str(i))
        plt.axis('off')
        plt.imshow(units[0, :, :, i], interpolation='nearest')

# %%
image = get_X_train_sample()
plt.imshow((image)[0], interpolation='nearest', )
#plt.figure(1, figsize=(10, 10))
plt.axis('off')
#plt.savefig('4_data.png', bbox_inches='tight')
plt.show()

# %%
def conv1_activations(x, conv_w1, conv_b1):
    ############################################################################
    # TODO: Compute activations for the first conv layer.                      #
    ############################################################################
    x1_1_pad = tf.pad(x, [[0, 0], [2, 2], [2, 2], [0, 0]], mode='CONSTANT', constant_values=0)
    x1_2_conv = tf.nn.conv2d(x1_1_pad, conv_w1, [1, 1, 1, 1], padding='VALID') + conv_b1
  
    ############################################################################
    #                             END OF YOUR CODE                             #
    ############################################################################
    return x1_2_conv

# %%
saver = tf.train.Saver()
with tf.Session() as sess:
    saver.restore(sess, "E:\\courses\\stat231A\\homework1\\models\\final_model.ckpt")
    x = tf.placeholder(tf.float32, [None, 32, 32, 3])
    hidden_1 = sess.run(conv1_activations(x, params[0], params[1]), feed_dict={x: image, params[0]: params_val[0], params[1]: params_val[1]})
    plot_filter_grid(hidden_1)
    #plt.savefig('5_activations.png', bbox_inches='tight')
    plt.show()

# %%
np.array(image).shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-746b66542d69> in <module>()
# ----> 1 np.array(image).shape
#
# NameError: name 'image' is not defined
