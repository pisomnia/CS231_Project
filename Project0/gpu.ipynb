# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 15590945078619664241
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 11281553818
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 2309702147474551084
# physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"
# ]

# %%
tf.Session().run(tf.random_uniform([4, 4]))
# Out:
# array([[0.87078786, 0.7040082 , 0.30958915, 0.8750156 ],
#        [0.1365788 , 0.79185927, 0.779122  , 0.72988224],
#        [0.84286845, 0.33839107, 0.1942383 , 0.14178455],
#        [0.26497817, 0.13061452, 0.657277  , 0.0770005 ]], dtype=float32)

# %%
# !pip3 install torch

import torch

torch.cuda.FloatTensor(4, 4).normal_()
# Out:
# ...
#     100% |████████████████████████████████| 519.5MB 34kB/s
# tcmalloc: large alloc 1073750016 bytes == 0x5a486000 @  0x7fb668afb2a4 0x594e17 0x626104 0x51190a 0x4f5277 0x510c78 0x5119bd 0x4f5277 0x4f3338 0x510fb0 0x5119bd 0x4f5277 0x4f3338 0x510fb0 0x5119bd 0x4f5277 0x4f3338 0x510fb0 0x5119bd 0x4f6070 0x510c78 0x5119bd 0x4f5277 0x4f3338 0x510fb0 0x5119bd 0x4f6070 0x4f3338 0x510fb0 0x5119bd 0x4f6070
# ...
# tensor([[-0.8872,  0.3096,  0.4188,  0.6787,  2.4020,  1.5215,  1.6670,  0.9263,
#          -0.5804, -0.2027],
#         [ 2.3347,  1.1768, -0.9412, -0.2330,  1.0127,  1.2605,  0.1482, -0.1849,
#           1.9420, -1.9148],
#         [ 1.7470, -2.8515, -1.3217, -0.2742,  0.3284, -0.6550, -0.1474, -0.1197,
#           1.0170,  0.5990],
#         [-1.4245, -1.6071,  0.5793, -0.1109, -0.0977, -0.5300,  0.7831,  0.6899,
#          -0.4179,  1.2358],
#         [-0.1565,  2.2917,  0.5401, -2.2694, -0.6189,  1.5960, -1.4291, -0.1773,
#           0.7179,  0.9177],
# ...
